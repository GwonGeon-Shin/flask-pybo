# %% [markdown]
# data_input_excel_to_db 버전에서는 db 갯수 조회와 add하는것을 적용시켰다.

# %% [markdown]
# data_input_excel_to_db_02 버전에서는 기존 db 갯수 조회 및 삭제, 이후 add 시키는것을 적용시킨다.

# %% [markdown]
# data_input_excel_to_db_03 버전에서는 기존 데이터 입력 방식의 개선을 진행한다.(0719추가 내용 확인)

# %% [markdown]
# ㄴ> 기존 기능 내용에 대해 풀어서 표시된것은 data_input_excel_to_db_02_for test <-- 를 참고하자

# %% [markdown]
# ▼▼▼ 이하 예제 시작(question_list에 적용하는것 => ss_project 적용)

# %%
#데이터 삭제 구현 완료 , 중간 하드코딩 건너띄고, 연속 데이터 입력 적용 확인

# %%
from pybo.models import Question, User
from pybo import db

from flask import Blueprint, url_for, render_template, flash, request, session

from werkzeug.security import generate_password_hash, check_password_hash
from werkzeug.utils import redirect

from flask import Flask
from flask_migrate import Migrate
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import MetaData
import config

import pybo

from openpyxl import load_workbook
from datetime import datetime
from pybo import db, create_app

from pybo import create_app
pybo = create_app()
pybo.app_context().push()

# %%
print(Question.query.count())
# Out:
# 20

# %%
print(User.query.count())
# Out:
# 9

# %%
app = Flask(__name__)
app.config.from_object(config)
    #app.config 환경 변수로 부르기 위해 app.config.from_object(config)코드를 추가함

# %%
#위에 까지가 기본 세팅 완료

# %%
#user 관련 확인용_220623

# %%
user_list_00=User.query.all()

# %%
user_list_00
# Out:
# [<User 2>, <User 4>, <User 6>, <User 7>, <User 8>]

# %%
a_user = user_list_00[0]

# %%
a_user
# Out:
# <User 2>

# %%
a_user.username
# Out:
# '관리자02'

# %%
# 데이터 삭제시 각 내용을 리스트화 해서 id값이 다르게 점프해도 삭제할수 있도록

# %%
query_list_00=Question.query.all()

# %%
len(query_list_00)
# Out:
# 899

# %%
query_list_00[0]
# Out:
# <Question 1>

# %%
query_test=Question.query.get(1000)
print(query_test)
# Out:
# <Question 1000>

# %%
# 데이터 삭제시 각 내용을 리스트화 해서 id값이 다르게 점프해도 삭제할수 있도록

# %%
# 개선 내용 테스트 해본다.

# %%
### 데이터 삭제 기능 개선_리스트화 적용
data_count = 0
query_list_00=Question.query.all()

with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ', Question.query.count())
    query_count_num = Question.query.count()
    
    for query_del_num in range(query_count_num):
        query_del_test = query_list_00[query_del_num]
        db.session.delete(query_del_test)
        db.session.commit()
        db.session.close()
        data_count = data_count+1
    
print("최종 작업 이후 Question모델 데이터 개수 : ", Question.query.count())
print("작업 진행 데이터 개수 : ", data_count)
# Out:
# 최초 시작시 Question모델 데이터 개수 :  6920
# 최종 작업 이후 Question모델 데이터 개수 :  0
# 작업 진행 데이터 개수 :  6920

# %% [markdown]
# ㄴ> 기존버전의 id값 기준 삭제하는 부분을 제거 하였다.

# %%
### 입력 부분 기능 시작

# %% [markdown]
# 이제 연속해서 하는걸 해보자

# %% [markdown]
# ▼▼▼▼ 데이터 입력부 시작

# %%
from openpyxl import load_workbook

# %%
wb = load_workbook(filename='db_test.xlsx')
ws = wb.active
ws
# Out:
# <Worksheet "Sheet1">

# %%
print(Question.query.count())
# Out:
# 0

# %%
a = 0
with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    for row in range(1, ws.max_row+1):
        try:
            #user = User(username='shin12352', password='shin_123452', email='shin52@naver.com')
            #user = User(username=ws.cell(row,1).value, password=ws.cell(row,2).value, email=ws.cell(row,3).value)
            question = Question(our_ref=ws.cell(row,1).value, pay_date=ws.cell(row,2).value, req_name=ws.cell(row,3).value, cus_name=ws.cell(row,4).value, date=ws.cell(row,5).value, number=ws.cell(row,6).value, q_date=ws.cell(row,7).value, q_d_date=ws.cell(row,8).value, d_d_date=ws.cell(row,9).value, d_d_num=ws.cell(row,10).value, p_name=ws.cell(row,11).value, charge_01=ws.cell(row,12).value, charge_02=ws.cell(row,13).value, p_charge=ws.cell(row,14).value, create_date=datetime.now())
            #user = User(username=ws.cell(row,1).value, password=ws.cell(row,2).value, email=ws.cell(row,3).value)
            #print(question)
            db.session.add(question)
            db.session.commit()
            #print('사용자 정보를 생성 하였습니다.')
        except:
            db.session.rollback()
            #print('입력에 에러가 발생 하였습니다.')
            pass
        finally:
            db.session.close()
        #print(a," 번째 작업을 종료 합니다.")
        a = a+1
        #print('='*10)

print("최종 작업 이후 Question모델 데이터 개수 : ", Question.query.count())
print("작업 진행 데이터 개수 : ", a)
# Out:
# 최초 시작시 Question모델 데이터 개수 :  0
# 최종 작업 이후 Question모델 데이터 개수 :  20
# 작업 진행 데이터 개수 :  20

# %% [markdown]
# ▲▲▲ 이상 예제 종료(question_list에 적용하는것 => ss_project 적용)

# %% [markdown]
# ▼▼▼▼ 이하 신규 데이터 입력부 시작_0719

# %%
from openpyxl import load_workbook

# %%
wb = load_workbook(filename='db_test.xlsx')
ws = wb.active
ws
# Out:
# <Worksheet "Sheet1">

# %%
print(Question.query.count())
# Out:
# 20

# %%
Question.query.all()
# Out:
# [<Question 1>,
#  <Question 2>,
#  <Question 3>,
#  <Question 4>,
#  <Question 5>,
#  <Question 6>,
#  <Question 7>,
#  <Question 8>,
#  <Question 9>,
#  <Question 10>,
#  <Question 11>,
#  <Question 12>,
#  <Question 13>,
#  <Question 14>,
#  <Question 15>,
#  <Question 16>,
#  <Question 17>,
#  <Question 18>,
#  <Question 19>,
#  <Question 20>]

# %%
q = Question.query.get(2)

# %%
q
# Out:
# <Question 2>

# %%
q.our_ref
# Out:
# 'D211115'

# %%
Question.query.filter(Question.our_ref.ilike('D211115')).all()
# Out:
# [<Question 2>]

# %%
test_b=Question.query.filter(Question.our_ref.ilike('D211115')).all()

# %%
test_b
# Out:
# [<Question 2>]

# %%
a = 0
same_count = 0
with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    for row in range(1, ws.max_row+1):
        print_ques=ws.cell(row,1).value
        #print_ques=ws.cell(row,3) <-- 위치값을 표시한다.
        print(print_ques)
# Out:
# 최초 시작시 Question모델 데이터 개수 :  20
# D211114
# D211115
# D211116
# P212398
# P212400
# P212412
# P211279-RE
# P212405
# P212418
# P212430-DIV1
# P212430-DIV2
# P212419
# P212420
# P212421
# P211363-PRO2
# P212441
# P209250-DIV1
# P212439-PRO1
# P212439-PRO2
# P212434-PRO1

# %% [markdown]
# 이 다음은 엑셀 파일에서 읽은값과 기존 question모델의 db 값과 같은지 확인해보자.

# %%
a = 0
same_count = 0
with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    for row in range(1, ws.max_row+1):
        # 엑셀 파일 내에 하나씩 읽어 오는 값을~~
        # 기존의 데이터와 비교해야 겠다.
        print_ques=ws.cell(row,1).value #<---- 엑셀 sheet의 our_ref값
        #print(print_ques)
        #엑셀 sheet의 our_ref값 기준으로
        #Question모델의 id값을 찾아보자. <-- 모델의 전체 값을 filter기능으로 찾는것 테스트
        test_bb=Question.query.filter(Question.our_ref.ilike(print_ques)).all()
        print(test_bb)
        # => db내 해당 자료값 찾기 완료
# Out:
# 최초 시작시 Question모델 데이터 개수 :  20
# [<Question 1>]
# [<Question 2>]
# [<Question 3>]
# [<Question 4>]
# [<Question 5>]
# [<Question 6>]
# [<Question 7>]
# [<Question 8>]
# [<Question 9>]
# [<Question 10>]
# [<Question 11>]
# [<Question 12>]
# [<Question 13>]
# [<Question 14>]
# [<Question 15>]
# [<Question 16>]
# [<Question 17>]
# [<Question 18>]
# [<Question 19>]
# [<Question 20>]

# %% [markdown]
# 활용 엑셀 파일 내 our_ref 값 기준 db내 해당값 찾기를 완료 하였다.

# %% [markdown]
# 이제 해당 내용을 수정할수 있도록 해보자.

# %%
a = 0
same_count = 0
test_bb=[]
with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    for row in range(1, ws.max_row+1):
        # 엑셀 파일 내에 하나씩 읽어 오는 값을~~
        # 기존의 데이터와 비교해야 겠다.
        print_ques=ws.cell(row,1).value #<---- 엑셀 sheet의 our_ref값
        #print(print_ques)
        
        #엑셀 sheet의 our_ref값 기준으로
        #Question모델의 id값을 찾아보자. <-- 모델의 전체 값을 filter기능으로 찾는것 테스트
        test_bb=Question.query.filter(Question.our_ref.ilike(print_ques)).all()
        #print(test_bb) #<-- 기존 리스트로 되어있다.
        
        
        test_bb_00 = test_bb[0] #<-- 리스트내 값만 가져온다.
        #print(test_bb_00)
        # => db내 해당 자료값 찾기 완료
        
        
        test_bb_00.our_ref=ws.cell(row,1).value
        #question_input=test_bb_00(our_ref=ws.cell(row,1).value, pay_date=ws.cell(row,2).value, req_name=ws.cell(row,3).value, cus_name=ws.cell(row,4).value, date=ws.cell(row,5).value, number=ws.cell(row,6).value, q_date=ws.cell(row,7).value, q_d_date=ws.cell(row,8).value, d_d_date=ws.cell(row,9).value, d_d_num=ws.cell(row,10).value, p_name=ws.cell(row,11).value, charge_01=ws.cell(row,12).value, charge_02=ws.cell(row,13).value, p_charge=ws.cell(row,14).value, create_date=datetime.now())
        db.session.commit()
        same_count = same_count +1
        print('작업단계 : ', same_count)
        
        #성공 ===>>> 중요!!! 해당 내용은 our_ref값 기준으로 데이터를 찾고 수정하는것이다.
        # 본 예제에서는 our_ref값도 동일하게 변경하였지만 이후, our_ref값을 변경시키지 말고 다른 데이터를
        # 변경 시키는것을 해라
# Out:
# 최초 시작시 Question모델 데이터 개수 :  20
# 작업단계 :  1
# 작업단계 :  2
# 작업단계 :  3
# 작업단계 :  4
# 작업단계 :  5
# 작업단계 :  6
# 작업단계 :  7
# 작업단계 :  8
# 작업단계 :  9
# 작업단계 :  10
# 작업단계 :  11
# 작업단계 :  12
# 작업단계 :  13
# 작업단계 :  14
# 작업단계 :  15
# 작업단계 :  16
# 작업단계 :  17
# 작업단계 :  18
# 작업단계 :  19
# 작업단계 :  20

# %% [markdown]
# ▲▲▲▲ 위에까지 일단 원하는 기능 구현하였다.

# %% [markdown]
# ▼▼▼▼ 아래서부터는 해당 기능 테스트와 개선을 진행한다. 2022-07-21

# %% [markdown]
# ▼▼ 이번에는 "데이터 수정 적용 테스트" 를 실행해본다. 위에서는 our_ref값을 수정하는것으로 했지만

# %% [markdown]
# 이제는 our_ref 기준으로 데이터 내 다른 열의 값을 수정하는 것을 목표로 하며 수정시 비어있는 cell 데이터가

# %% [markdown]
# 어떻게 적용되는지(에러없이 되는지) 확인하는 단계이다.

# %%
a = 0
same_count = 0
test_bb=[]
with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    for row in range(1, ws.max_row+1):
        # 엑셀 파일 내에 하나씩 읽어 오는 값을~~
        # 기존의 데이터와 비교해야 겠다.
        print_ques=ws.cell(row,1).value #<---- 엑셀 sheet의 our_ref값
        #print(print_ques)
        
        #엑셀 sheet의 our_ref값 기준으로
        #Question모델의 id값을 찾아보자. <-- 모델의 전체 값을 filter기능으로 찾는것 테스트
        test_bb=Question.query.filter(Question.our_ref.ilike(print_ques)).all()
        #print(test_bb) #<-- 기존 리스트로 되어있다.
        
        
        test_bb_00 = test_bb[0] #<-- 리스트내 값만 가져온다.
        #print(test_bb_00)
        # => db내 해당 자료값 찾기 완료
        
        """
        ▼▼▼ 이하 our_ref 값 기준으로 데이터네 열 값 수정 테스트 진행
        """
        #test_bb_00.our_ref=ws.cell(row,1).value #<--- 해당 부분
        test_bb_00.pay_date=ws.cell(row,2).value #<--- pay_date 기준 적용되게(해당부분 null값 존재)
        
        #question_input=test_bb_00(our_ref=ws.cell(row,1).value, pay_date=ws.cell(row,2).value, req_name=ws.cell(row,3).value, cus_name=ws.cell(row,4).value, date=ws.cell(row,5).value, number=ws.cell(row,6).value, q_date=ws.cell(row,7).value, q_d_date=ws.cell(row,8).value, d_d_date=ws.cell(row,9).value, d_d_num=ws.cell(row,10).value, p_name=ws.cell(row,11).value, charge_01=ws.cell(row,12).value, charge_02=ws.cell(row,13).value, p_charge=ws.cell(row,14).value, create_date=datetime.now())
        db.session.commit()
        same_count = same_count +1
        print('작업단계 : ', same_count)
        """
        ▲▲▲
        """
        
        #성공 ===>>> 중요!!! 해당 내용은 our_ref값 기준으로 데이터를 찾고 수정하는것이다.
        # 본 예제에서는 our_ref값도 동일하게 변경하였지만 이후, our_ref값을 변경시키지 말고 다른 데이터를
        # 변경 시키는것을 해라
# Out:
# 최초 시작시 Question모델 데이터 개수 :  20
# 작업단계 :  1
# 작업단계 :  2
# 작업단계 :  3
# 작업단계 :  4
# 작업단계 :  5
# 작업단계 :  6
# 작업단계 :  7
# 작업단계 :  8
# 작업단계 :  9
# 작업단계 :  10
# 작업단계 :  11
# 작업단계 :  12
# 작업단계 :  13
# 작업단계 :  14
# 작업단계 :  15
# 작업단계 :  16
# 작업단계 :  17
# 작업단계 :  18
# 작업단계 :  19
# 작업단계 :  20

# %% [markdown]
# ▲▲  "데이터 수정 적용 테스트"  성공

# %% [markdown]
# ▼▼ 데이터 업로드 기능 수정하기_02_시작_220721

# %% [markdown]
# 목표 : 엑셀 데이터 sheet에서 가져온 our_ref값이 데이터파일내 our_ref값중 해당되는게 있는지 참,거짓 형태로 출력하기(if문)

# %%
a = 0
same_count = 0
test_bb=[]
with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    print('='*15)
    for row in range(1, ws.max_row+1):
        # 엑셀 파일 내에 하나씩 읽어 오는 값을~~
        # 기존의 데이터와 비교해야 겠다.
        print_ques=ws.cell(row,1).value #<---- 엑셀 sheet의 our_ref값
        print('엑셀 파일의 our_ref : ',print_ques)
        
        test_bb = Question.query.filter(Question.our_ref.ilike(print_ques)).all()
        test_bb_00 = test_bb[0]
        test_bb_01 = test_bb_00.our_ref
        print('데이터 파일의 해당 id값 : ',test_bb)
        print('데이터 파일의 our_ref : ',test_bb_01)
        
        if print_ques in test_bb_01:
            same_count = same_count+1
            print('리스트에 있음 : ', same_count)
            print('='*15)
        else:
            print('리스트에 없음')
            print('='*15)
# Out:
# 최초 시작시 Question모델 데이터 개수 :  20
# ===============
# 엑셀 파일의 our_ref :  D211114
# 데이터 파일의 해당 id값 :  [<Question 1>]
# 데이터 파일의 our_ref :  D211114
# 리스트에 있음 :  1
# ===============
# 엑셀 파일의 our_ref :  D211115
# 데이터 파일의 해당 id값 :  [<Question 2>]
# 데이터 파일의 our_ref :  D211115
# 리스트에 있음 :  2
# ===============
# 엑셀 파일의 our_ref :  D211116
# 데이터 파일의 해당 id값 :  [<Question 3>]
# 데이터 파일의 our_ref :  D211116
# 리스트에 있음 :  3
# ===============
# 엑셀 파일의 our_ref :  P212398
# 데이터 파일의 해당 id값 :  [<Question 4>]
# 데이터 파일의 our_ref :  P212398
# 리스트에 있음 :  4
# ===============
# 엑셀 파일의 our_ref :  P212400
# 데이터 파일의 해당 id값 :  [<Question 5>]
# 데이터 파일의 our_ref :  P212400
# 리스트에 있음 :  5
# ===============
# 엑셀 파일의 our_ref :  P212412
# 데이터 파일의 해당 id값 :  [<Question 6>]
# 데이터 파일의 our_ref :  P212412
# 리스트에 있음 :  6
# ===============
# 엑셀 파일의 our_ref :  P211279-RE
# 데이터 파일의 해당 id값 :  [<Question 7>]
# 데이터 파일의 our_ref :  P211279-RE
# 리스트에 있음 :  7
# ===============
# 엑셀 파일의 our_ref :  P212405
# 데이터 파일의 해당 id값 :  [<Question 8>]
# 데이터 파일의 our_ref :  P212405
# 리스트에 있음 :  8
# ===============
# 엑셀 파일의 our_ref :  P212418
# 데이터 파일의 해당 id값 :  [<Question 9>]
# 데이터 파일의 our_ref :  P212418
# 리스트에 있음 :  9
# ===============
# 엑셀 파일의 our_ref :  P212430-DIV1
# 데이터 파일의 해당 id값 :  [<Question 10>]
# 데이터 파일의 our_ref :  P212430-DIV1
# 리스트에 있음 :  10
# ===============
# 엑셀 파일의 our_ref :  P212430-DIV2
# 데이터 파일의 해당 id값 :  [<Question 11>]
# 데이터 파일의 our_ref :  P212430-DIV2
# 리스트에 있음 :  11
# ===============
# 엑셀 파일의 our_ref :  P212419
# 데이터 파일의 해당 id값 :  [<Question 12>]
# 데이터 파일의 our_ref :  P212419
# 리스트에 있음 :  12
# ===============
# 엑셀 파일의 our_ref :  P212420
# 데이터 파일의 해당 id값 :  [<Question 13>]
# 데이터 파일의 our_ref :  P212420
# 리스트에 있음 :  13
# ===============
# 엑셀 파일의 our_ref :  P212421
# 데이터 파일의 해당 id값 :  [<Question 14>]
# 데이터 파일의 our_ref :  P212421
# 리스트에 있음 :  14
# ===============
# 엑셀 파일의 our_ref :  P211363-PRO2
# 데이터 파일의 해당 id값 :  [<Question 15>]
# 데이터 파일의 our_ref :  P211363-PRO2
# 리스트에 있음 :  15
# ===============
# 엑셀 파일의 our_ref :  P212441
# 데이터 파일의 해당 id값 :  [<Question 16>]
# 데이터 파일의 our_ref :  P212441
# 리스트에 있음 :  16
# ===============
# 엑셀 파일의 our_ref :  P209250-DIV1
# 데이터 파일의 해당 id값 :  [<Question 17>]
# 데이터 파일의 our_ref :  P209250-DIV1
# 리스트에 있음 :  17
# ===============
# 엑셀 파일의 our_ref :  P212439-PRO1
# 데이터 파일의 해당 id값 :  [<Question 18>]
# 데이터 파일의 our_ref :  P212439-PRO1
# 리스트에 있음 :  18
# ===============
# 엑셀 파일의 our_ref :  P212439-PRO2
# 데이터 파일의 해당 id값 :  [<Question 19>]
# 데이터 파일의 our_ref :  P212439-PRO2
# 리스트에 있음 :  19
# ===============
# 엑셀 파일의 our_ref :  P212434-PRO1
# 데이터 파일의 해당 id값 :  [<Question 20>]
# 데이터 파일의 our_ref :  P212434-PRO1
# 리스트에 있음 :  20
# ===============

# %% [markdown]
# ▼▼모델(Question) id값 기준으로 id에 해당되는 속성값(our_ref, pay_date) 출력해보기

# %%
test_bb_test=Question.query.filter(Question.our_ref.ilike(print_ques)).all()

# %%
test_bb_test[0]
# Out:
# <Question 1>

# %%
test_bb_test_00=test_bb_test[0]

# %%
test_bb_test_00.our_ref
# Out:
# 'D211114'

# %%
test_bb_test_00.pay_date
# Out:
# '날짜1'

# %% [markdown]
# ▲▲ 데이터 업로드 기능 수정하기_02_성공_220721

# %% [markdown]
# ▼▼ 데이터 업로드 기능 수정하기_03_시작_220721

# %%
from openpyxl import load_workbook
wb = load_workbook(filename='db_test.xlsx')
ws = wb.active

a = 0
same_count = 0
test_bb=[]
test_bb_01=[]

with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    print('='*15)
    for row in range(1, ws.max_row+1):
        # 엑셀 파일 내에 하나씩 읽어 오는 값을~~
        # 기존의 데이터와 비교해야 겠다.
        print_ques=ws.cell(row,1).value #<---- 엑셀 sheet의 our_ref값
        print('엑셀 파일의 our_ref : ',print_ques)
        
        """
        엑셀파일 내 our_ref 기준값이 db 파일내 없을시 검색에 오류 발생을 예상해서
        try except 적용시킨다.
        """
        try:
            test_bb = Question.query.filter(Question.our_ref.ilike(print_ques)).all()
            test_bb_00 = test_bb[0]
            test_bb_01 = test_bb_00.our_ref #our_ref값만 적용되는 변수 "test_bb_01"
            print('데이터 파일의 해당 id값 : ',test_bb)
            print('데이터 파일의 our_ref : ',test_bb_01)
        except:
            #print("데이터 파일 내 일치 our_ref 없음")
            pass
        
        
        
        if print_ques in test_bb_01:
            '''
            해당 부분 코드는
            our_ref값 기준 엑셀파일과,db파일내 동일 our_ref값이 존재하기에 값을 수정한다.
            위의 "데이터 수정 적용 테스트" 예제를 확인할것
            '''
            test_bb_00.pay_date=ws.cell(row,2).value
            db.session.commit()
            
            same_count = same_count+1
            print('데이터 파일 내 일치 our_ref 존재 : ', same_count)
            print('='*15)
        else:
            same_count = same_count+1
            print('데이터 파일 내 일치 our_ref 없음', same_count)
            print('='*15)
# Out:
# 최초 시작시 Question모델 데이터 개수 :  20
# ===============
# 엑셀 파일의 our_ref :  D211114
# 데이터 파일의 해당 id값 :  [<Question 1>]
# 데이터 파일의 our_ref :  D211114
# 데이터 파일 내 일치 our_ref 존재 :  1
# ===============
# 엑셀 파일의 our_ref :  D211115
# 데이터 파일의 해당 id값 :  [<Question 2>]
# 데이터 파일의 our_ref :  D211115
# 데이터 파일 내 일치 our_ref 존재 :  2
# ===============
# 엑셀 파일의 our_ref :  D211116
# 데이터 파일의 해당 id값 :  [<Question 3>]
# 데이터 파일의 our_ref :  D211116
# 데이터 파일 내 일치 our_ref 존재 :  3
# ===============
# 엑셀 파일의 our_ref :  P212398
# 데이터 파일의 해당 id값 :  [<Question 4>]
# 데이터 파일의 our_ref :  P212398
# 데이터 파일 내 일치 our_ref 존재 :  4
# ===============
# 엑셀 파일의 our_ref :  P212400
# 데이터 파일의 해당 id값 :  [<Question 5>]
# 데이터 파일의 our_ref :  P212400
# 데이터 파일 내 일치 our_ref 존재 :  5
# ===============
# 엑셀 파일의 our_ref :  P212412
# 데이터 파일의 해당 id값 :  [<Question 6>]
# 데이터 파일의 our_ref :  P212412
# 데이터 파일 내 일치 our_ref 존재 :  6
# ===============
# 엑셀 파일의 our_ref :  P211279-RE
# 데이터 파일의 해당 id값 :  [<Question 7>]
# 데이터 파일의 our_ref :  P211279-RE
# 데이터 파일 내 일치 our_ref 존재 :  7
# ===============
# 엑셀 파일의 our_ref :  P212405
# 데이터 파일의 해당 id값 :  [<Question 8>]
# 데이터 파일의 our_ref :  P212405
# 데이터 파일 내 일치 our_ref 존재 :  8
# ===============
# 엑셀 파일의 our_ref :  P212418
# 데이터 파일의 해당 id값 :  [<Question 9>]
# 데이터 파일의 our_ref :  P212418
# 데이터 파일 내 일치 our_ref 존재 :  9
# ===============
# 엑셀 파일의 our_ref :  P212430-DIV1
# 데이터 파일의 해당 id값 :  [<Question 10>]
# 데이터 파일의 our_ref :  P212430-DIV1
# 데이터 파일 내 일치 our_ref 존재 :  10
# ===============
# 엑셀 파일의 our_ref :  P212430-DIV2
# 데이터 파일의 해당 id값 :  [<Question 11>]
# 데이터 파일의 our_ref :  P212430-DIV2
# 데이터 파일 내 일치 our_ref 존재 :  11
# ===============
# 엑셀 파일의 our_ref :  P212419
# 데이터 파일의 해당 id값 :  [<Question 12>]
# 데이터 파일의 our_ref :  P212419
# 데이터 파일 내 일치 our_ref 존재 :  12
# ===============
# 엑셀 파일의 our_ref :  P212420
# 데이터 파일의 해당 id값 :  [<Question 13>]
# 데이터 파일의 our_ref :  P212420
# 데이터 파일 내 일치 our_ref 존재 :  13
# ===============
# 엑셀 파일의 our_ref :  P212421
# 데이터 파일의 해당 id값 :  [<Question 14>]
# 데이터 파일의 our_ref :  P212421
# 데이터 파일 내 일치 our_ref 존재 :  14
# ===============
# 엑셀 파일의 our_ref :  P211363-PRO2
# 데이터 파일의 해당 id값 :  [<Question 15>]
# 데이터 파일의 our_ref :  P211363-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  15
# ===============
# 엑셀 파일의 our_ref :  P212441
# 데이터 파일의 해당 id값 :  [<Question 16>]
# 데이터 파일의 our_ref :  P212441
# 데이터 파일 내 일치 our_ref 존재 :  16
# ===============
# 엑셀 파일의 our_ref :  P209250-DIV1
# 데이터 파일의 해당 id값 :  [<Question 17>]
# 데이터 파일의 our_ref :  P209250-DIV1
# 데이터 파일 내 일치 our_ref 존재 :  17
# ===============
# 엑셀 파일의 our_ref :  P212439-PRO1
# 데이터 파일의 해당 id값 :  [<Question 18>]
# 데이터 파일의 our_ref :  P212439-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  18
# ===============
# 엑셀 파일의 our_ref :  P212439-PRO2
# 데이터 파일의 해당 id값 :  [<Question 19>]
# 데이터 파일의 our_ref :  P212439-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  19
# ===============
# 엑셀 파일의 our_ref :  P212434-PRO1
# 데이터 파일의 해당 id값 :  [<Question 20>]
# 데이터 파일의 our_ref :  P212434-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  20
# ===============
# 엑셀 파일의 our_ref :  P212434-PRO100
# 데이터 파일 내 일치 our_ref 없음 21
# ===============

# %% [markdown]
# 3. '데이터 파일 내 일치 our_ref 없음' 일시, 데이터 신규로 작성하기 구현

# %%
from openpyxl import load_workbook
wb = load_workbook(filename='db_test.xlsx')
ws = wb.active

a = 0
same_count = 0
test_bb=[]
test_bb_01=[]

with app.app_context():
    print('최초 시작시 Question모델 데이터 개수 : ',Question.query.count())
    print('='*15)
    for row in range(1, ws.max_row+1):
        # 엑셀 파일 내에 하나씩 읽어 오는 값을~~
        # 기존의 데이터와 비교해야 겠다.
        print_ques=ws.cell(row,1).value #<---- 엑셀 sheet의 our_ref값
        print('엑셀 파일의 our_ref : ',print_ques)
        
        """
        엑셀파일 내 our_ref 기준값이 db 파일내 없을시 검색에 오류 발생을 예상해서
        try except 적용시킨다.
        """
        try:
            test_bb = Question.query.filter(Question.our_ref.ilike(print_ques)).all()
            test_bb_00 = test_bb[0]
            test_bb_01 = test_bb_00.our_ref #our_ref값만 적용되는 변수 "test_bb_01"
            print('데이터 파일의 해당 id값 : ',test_bb)
            print('데이터 파일의 our_ref : ',test_bb_01)
        except:
            #print("데이터 파일 내 일치 our_ref 없음")
            pass
        
        
        
        if print_ques in test_bb_01:
            '''
            해당 부분 코드는
            our_ref값 기준 엑셀파일과,db파일내 동일 our_ref값이 존재하기에 값을 수정한다.
            위의 "데이터 수정 적용 테스트" 예제를 확인할것
            '''
            test_bb_00.pay_date=ws.cell(row,2).value #<--- 부분은 pay_date만 수정하도록 한것
            test_bb_00.req_name=ws.cell(row,3).value
            test_bb_00.cus_name=ws.cell(row,4).value
            test_bb_00.date=ws.cell(row,5).value
            test_bb_00.number=ws.cell(row,6).value
            test_bb_00.q_date=ws.cell(row,7).value
            test_bb_00.q_d_date=ws.cell(row,8).value
            test_bb_00.d_d_date=ws.cell(row,9).value
            test_bb_00.d_d_num=ws.cell(row,10).value
            test_bb_00.p_name=ws.cell(row,11).value
            test_bb_00.charge_01=ws.cell(row,12).value
            test_bb_00.charge_02=ws.cell(row,13).value
            test_bb_00.p_charge=ws.cell(row,14).value
            db.session.commit()
            
            same_count = same_count+1
            print('데이터 파일 내 일치 our_ref 존재 : ', same_count)
            print('='*15)
        else:
            '''
            our_ref값 기준 엑셀파일과, db파일내 동일 our_ref값 없을때
            엑셀파일의 내용을 db파일내 작성하는 코드
            '''
            try:
                question = Question(our_ref=ws.cell(row,1).value, pay_date=ws.cell(row,2).value, req_name=ws.cell(row,3).value, cus_name=ws.cell(row,4).value, date=ws.cell(row,5).value, number=ws.cell(row,6).value, q_date=ws.cell(row,7).value, q_d_date=ws.cell(row,8).value, d_d_date=ws.cell(row,9).value, d_d_num=ws.cell(row,10).value, p_name=ws.cell(row,11).value, charge_01=ws.cell(row,12).value, charge_02=ws.cell(row,13).value, p_charge=ws.cell(row,14).value, create_date=datetime.now())
                db.session.add(question)
                db.session.commit()
                print('엑셀 our_ref 정보를 db파일내 생성 하였습니다.')
            except:
                db.session.rollback()
                print('입력에 에러가 발생 하였습니다.')
                pass
            finally:
                db.session.close()
            
            same_count = same_count+1
            print('데이터 파일 내 신규 작성', same_count)
            print('='*15)
# Out:
# 최초 시작시 Question모델 데이터 개수 :  6920
# ===============
# 엑셀 파일의 our_ref :  T198168
# 데이터 파일의 해당 id값 :  [<Question 1>]
# 데이터 파일의 our_ref :  T198168
# 데이터 파일 내 일치 our_ref 존재 :  1
# ===============
# 엑셀 파일의 our_ref :  P198222
# 데이터 파일의 해당 id값 :  [<Question 2>]
# 데이터 파일의 our_ref :  P198222
# 데이터 파일 내 일치 our_ref 존재 :  2
# ===============
# 엑셀 파일의 our_ref :  P208144
# 데이터 파일의 해당 id값 :  [<Question 3>]
# 데이터 파일의 our_ref :  P208144
# 데이터 파일 내 일치 our_ref 존재 :  3
# ===============
# 엑셀 파일의 our_ref :  P211001
# 데이터 파일의 해당 id값 :  [<Question 4>]
# 데이터 파일의 our_ref :  P211001
# 데이터 파일 내 일치 our_ref 존재 :  4
# ===============
# 엑셀 파일의 our_ref :  PI208005 (19IP-728HU)
# 데이터 파일의 해당 id값 :  [<Question 5>]
# 데이터 파일의 our_ref :  PI208005 (19IP-728HU)
# 데이터 파일 내 일치 our_ref 존재 :  5
# ===============
# 엑셀 파일의 our_ref :  P208571
# 데이터 파일의 해당 id값 :  [<Question 6>]
# 데이터 파일의 our_ref :  P208571
# 데이터 파일 내 일치 our_ref 존재 :  6
# ===============
# 엑셀 파일의 our_ref :  P208653
# 데이터 파일의 해당 id값 :  [<Question 7>]
# 데이터 파일의 our_ref :  P208653
# 데이터 파일 내 일치 our_ref 존재 :  7
# ===============
# 엑셀 파일의 our_ref :  T208280
# 데이터 파일의 해당 id값 :  [<Question 8>]
# 데이터 파일의 our_ref :  T208280
# 데이터 파일 내 일치 our_ref 존재 :  8
# ===============
# 엑셀 파일의 our_ref :  T208159
# 데이터 파일의 해당 id값 :  [<Question 9>]
# 데이터 파일의 our_ref :  T208159
# 데이터 파일 내 일치 our_ref 존재 :  9
# ===============
# 엑셀 파일의 our_ref :  P208655
# 데이터 파일의 해당 id값 :  [<Question 10>]
# 데이터 파일의 our_ref :  P208655
# 데이터 파일 내 일치 our_ref 존재 :  10
# ===============
# 엑셀 파일의 our_ref :  P208274
# 데이터 파일의 해당 id값 :  [<Question 11>]
# 데이터 파일의 our_ref :  P208274
# 데이터 파일 내 일치 our_ref 존재 :  11
# ===============
# 엑셀 파일의 our_ref :  P208262
# 데이터 파일의 해당 id값 :  [<Question 12>]
# 데이터 파일의 our_ref :  P208262
# 데이터 파일 내 일치 our_ref 존재 :  12
# ===============
# 엑셀 파일의 our_ref :  P208272
# 데이터 파일의 해당 id값 :  [<Question 13>]
# 데이터 파일의 our_ref :  P208272
# 데이터 파일 내 일치 our_ref 존재 :  13
# ===============
# 엑셀 파일의 our_ref :  T208057
# 데이터 파일의 해당 id값 :  [<Question 14>]
# 데이터 파일의 our_ref :  T208057
# 데이터 파일 내 일치 our_ref 존재 :  14
# ===============
# 엑셀 파일의 our_ref :  P208275
# 데이터 파일의 해당 id값 :  [<Question 15>]
# 데이터 파일의 our_ref :  P208275
# 데이터 파일 내 일치 our_ref 존재 :  15
# ===============
# 엑셀 파일의 our_ref :  P208197
# 데이터 파일의 해당 id값 :  [<Question 16>]
# 데이터 파일의 our_ref :  P208197
# 데이터 파일 내 일치 our_ref 존재 :  16
# ===============
# 엑셀 파일의 our_ref :  T208055
# 데이터 파일의 해당 id값 :  [<Question 17>]
# 데이터 파일의 our_ref :  T208055
# 데이터 파일 내 일치 our_ref 존재 :  17
# ===============
# 엑셀 파일의 our_ref :  P208170
# 데이터 파일의 해당 id값 :  [<Question 18>]
# 데이터 파일의 our_ref :  P208170
# 데이터 파일 내 일치 our_ref 존재 :  18
# ===============
# 엑셀 파일의 our_ref :  T208059
# 데이터 파일의 해당 id값 :  [<Question 19>]
# 데이터 파일의 our_ref :  T208059
# 데이터 파일 내 일치 our_ref 존재 :  19
# ===============
# 엑셀 파일의 our_ref :  T208061
# 데이터 파일의 해당 id값 :  [<Question 20>]
# 데이터 파일의 our_ref :  T208061
# 데이터 파일 내 일치 our_ref 존재 :  20
# ===============
# 엑셀 파일의 our_ref :  P208203
# 데이터 파일의 해당 id값 :  [<Question 21>]
# 데이터 파일의 our_ref :  P208203
# 데이터 파일 내 일치 our_ref 존재 :  21
# ===============
# 엑셀 파일의 our_ref :  P208149
# 데이터 파일의 해당 id값 :  [<Question 22>]
# 데이터 파일의 our_ref :  P208149
# 데이터 파일 내 일치 our_ref 존재 :  22
# ===============
# 엑셀 파일의 our_ref :  T208065
# 데이터 파일의 해당 id값 :  [<Question 23>]
# 데이터 파일의 our_ref :  T208065
# 데이터 파일 내 일치 our_ref 존재 :  23
# ===============
# 엑셀 파일의 our_ref :  T208062
# 데이터 파일의 해당 id값 :  [<Question 24>]
# 데이터 파일의 our_ref :  T208062
# 데이터 파일 내 일치 our_ref 존재 :  24
# ===============
# 엑셀 파일의 our_ref :  P208153
# 데이터 파일의 해당 id값 :  [<Question 25>]
# 데이터 파일의 our_ref :  P208153
# 데이터 파일 내 일치 our_ref 존재 :  25
# ===============
# 엑셀 파일의 our_ref :  P208089
# 데이터 파일의 해당 id값 :  [<Question 26>]
# 데이터 파일의 our_ref :  P208089
# 데이터 파일 내 일치 our_ref 존재 :  26
# ===============
# 엑셀 파일의 our_ref :  T208041
# 데이터 파일의 해당 id값 :  [<Question 27>]
# 데이터 파일의 our_ref :  T208041
# 데이터 파일 내 일치 our_ref 존재 :  27
# ===============
# 엑셀 파일의 our_ref :  P208091
# 데이터 파일의 해당 id값 :  [<Question 28>]
# 데이터 파일의 our_ref :  P208091
# 데이터 파일 내 일치 our_ref 존재 :  28
# ===============
# 엑셀 파일의 our_ref :  P208092
# 데이터 파일의 해당 id값 :  [<Question 29>]
# 데이터 파일의 our_ref :  P208092
# 데이터 파일 내 일치 our_ref 존재 :  29
# ===============
# 엑셀 파일의 our_ref :  P208158
# 데이터 파일의 해당 id값 :  [<Question 30>]
# 데이터 파일의 our_ref :  P208158
# 데이터 파일 내 일치 our_ref 존재 :  30
# ===============
# 엑셀 파일의 our_ref :  T208045
# 데이터 파일의 해당 id값 :  [<Question 31>]
# 데이터 파일의 our_ref :  T208045
# 데이터 파일 내 일치 our_ref 존재 :  31
# ===============
# 엑셀 파일의 our_ref :  T208097
# 데이터 파일의 해당 id값 :  [<Question 32>]
# 데이터 파일의 our_ref :  T208097
# 데이터 파일 내 일치 our_ref 존재 :  32
# ===============
# 엑셀 파일의 our_ref :  T208074
# 데이터 파일의 해당 id값 :  [<Question 33>]
# 데이터 파일의 our_ref :  T208074
# 데이터 파일 내 일치 our_ref 존재 :  33
# ===============
# 엑셀 파일의 our_ref :  P208097
# 데이터 파일의 해당 id값 :  [<Question 34>]
# 데이터 파일의 our_ref :  P208097
# 데이터 파일 내 일치 our_ref 존재 :  34
# ===============
# 엑셀 파일의 our_ref :  P208098
# 데이터 파일의 해당 id값 :  [<Question 35>]
# 데이터 파일의 our_ref :  P208098
# 데이터 파일 내 일치 our_ref 존재 :  35
# ===============
# 엑셀 파일의 our_ref :  P208169
# 데이터 파일의 해당 id값 :  [<Question 36>]
# 데이터 파일의 our_ref :  P208169
# 데이터 파일 내 일치 our_ref 존재 :  36
# ===============
# 엑셀 파일의 our_ref :  P208106
# 데이터 파일의 해당 id값 :  [<Question 37>]
# 데이터 파일의 our_ref :  P208106
# 데이터 파일 내 일치 our_ref 존재 :  37
# ===============
# 엑셀 파일의 our_ref :  P208108
# 데이터 파일의 해당 id값 :  [<Question 38>]
# 데이터 파일의 our_ref :  P208108
# 데이터 파일 내 일치 our_ref 존재 :  38
# ===============
# 엑셀 파일의 our_ref :  T208043
# 데이터 파일의 해당 id값 :  [<Question 39>]
# 데이터 파일의 our_ref :  T208043
# 데이터 파일 내 일치 our_ref 존재 :  39
# ===============
# 엑셀 파일의 our_ref :  T208076
# 데이터 파일의 해당 id값 :  [<Question 40>]
# 데이터 파일의 our_ref :  T208076
# 데이터 파일 내 일치 our_ref 존재 :  40
# ===============
# 엑셀 파일의 our_ref :  T198394
# 데이터 파일의 해당 id값 :  [<Question 41>]
# 데이터 파일의 our_ref :  T198394
# 데이터 파일 내 일치 our_ref 존재 :  41
# ===============
# 엑셀 파일의 our_ref :  T208031
# 데이터 파일의 해당 id값 :  [<Question 42>]
# 데이터 파일의 our_ref :  T208031
# 데이터 파일 내 일치 our_ref 존재 :  42
# ===============
# 엑셀 파일의 our_ref :  D208008
# 데이터 파일의 해당 id값 :  [<Question 43>]
# 데이터 파일의 our_ref :  D208008
# 데이터 파일 내 일치 our_ref 존재 :  43
# ===============
# 엑셀 파일의 our_ref :  P208039
# 데이터 파일의 해당 id값 :  [<Question 44>]
# 데이터 파일의 our_ref :  P208039
# 데이터 파일 내 일치 our_ref 존재 :  44
# ===============
# 엑셀 파일의 our_ref :  P198338
# 데이터 파일의 해당 id값 :  [<Question 45>]
# 데이터 파일의 our_ref :  P198338
# 데이터 파일 내 일치 our_ref 존재 :  45
# ===============
# 엑셀 파일의 our_ref :  P198341
# 데이터 파일의 해당 id값 :  [<Question 46>]
# 데이터 파일의 our_ref :  P198341
# 데이터 파일 내 일치 our_ref 존재 :  46
# ===============
# 엑셀 파일의 our_ref :  T208044
# 데이터 파일의 해당 id값 :  [<Question 47>]
# 데이터 파일의 our_ref :  T208044
# 데이터 파일 내 일치 our_ref 존재 :  47
# ===============
# 엑셀 파일의 our_ref :  P208027
# 데이터 파일의 해당 id값 :  [<Question 48>]
# 데이터 파일의 our_ref :  P208027
# 데이터 파일 내 일치 our_ref 존재 :  48
# ===============
# 엑셀 파일의 our_ref :  T208089
# 데이터 파일의 해당 id값 :  [<Question 49>]
# 데이터 파일의 our_ref :  T208089
# 데이터 파일 내 일치 our_ref 존재 :  49
# ===============
# 엑셀 파일의 our_ref :  T208090
# 데이터 파일의 해당 id값 :  [<Question 50>]
# 데이터 파일의 our_ref :  T208090
# 데이터 파일 내 일치 our_ref 존재 :  50
# ===============
# 엑셀 파일의 our_ref :  T208091
# 데이터 파일의 해당 id값 :  [<Question 51>]
# 데이터 파일의 our_ref :  T208091
# 데이터 파일 내 일치 our_ref 존재 :  51
# ===============
# 엑셀 파일의 our_ref :  P198243
# 데이터 파일의 해당 id값 :  [<Question 52>]
# 데이터 파일의 our_ref :  P198243
# 데이터 파일 내 일치 our_ref 존재 :  52
# ===============
# 엑셀 파일의 our_ref :  P208177
# 데이터 파일의 해당 id값 :  [<Question 53>]
# 데이터 파일의 our_ref :  P208177
# 데이터 파일 내 일치 our_ref 존재 :  53
# ===============
# 엑셀 파일의 our_ref :  T198320
# 데이터 파일의 해당 id값 :  [<Question 54>]
# 데이터 파일의 our_ref :  T198320
# 데이터 파일 내 일치 our_ref 존재 :  54
# ===============
# 엑셀 파일의 our_ref :  P198297
# 데이터 파일의 해당 id값 :  [<Question 55>]
# 데이터 파일의 our_ref :  P198297
# 데이터 파일 내 일치 our_ref 존재 :  55
# ===============
# 엑셀 파일의 our_ref :  T198331
# 데이터 파일의 해당 id값 :  [<Question 56>]
# 데이터 파일의 our_ref :  T198331
# 데이터 파일 내 일치 our_ref 존재 :  56
# ===============
# 엑셀 파일의 our_ref :  T198403
# 데이터 파일의 해당 id값 :  [<Question 57>]
# 데이터 파일의 our_ref :  T198403
# 데이터 파일 내 일치 our_ref 존재 :  57
# ===============
# 엑셀 파일의 our_ref :  T198404
# 데이터 파일의 해당 id값 :  [<Question 58>]
# 데이터 파일의 our_ref :  T198404
# 데이터 파일 내 일치 our_ref 존재 :  58
# ===============
# 엑셀 파일의 our_ref :  T198408
# 데이터 파일의 해당 id값 :  [<Question 59>]
# 데이터 파일의 our_ref :  T198408
# 데이터 파일 내 일치 our_ref 존재 :  59
# ===============
# 엑셀 파일의 our_ref :  P198225
# 데이터 파일의 해당 id값 :  [<Question 60>]
# 데이터 파일의 our_ref :  P198225
# 데이터 파일 내 일치 our_ref 존재 :  60
# ===============
# 엑셀 파일의 our_ref :  T198284
# 데이터 파일의 해당 id값 :  [<Question 61>]
# 데이터 파일의 our_ref :  T198284
# 데이터 파일 내 일치 our_ref 존재 :  61
# ===============
# 엑셀 파일의 our_ref :  T198400
# 데이터 파일의 해당 id값 :  [<Question 62>]
# 데이터 파일의 our_ref :  T198400
# 데이터 파일 내 일치 our_ref 존재 :  62
# ===============
# 엑셀 파일의 our_ref :  T208084
# 데이터 파일의 해당 id값 :  [<Question 63>]
# 데이터 파일의 our_ref :  T208084
# 데이터 파일 내 일치 our_ref 존재 :  63
# ===============
# 엑셀 파일의 our_ref :  P208184
# 데이터 파일의 해당 id값 :  [<Question 64>]
# 데이터 파일의 our_ref :  P208184
# 데이터 파일 내 일치 our_ref 존재 :  64
# ===============
# 엑셀 파일의 our_ref :  T198319
# 데이터 파일의 해당 id값 :  [<Question 65>]
# 데이터 파일의 our_ref :  T198319
# 데이터 파일 내 일치 our_ref 존재 :  65
# ===============
# 엑셀 파일의 our_ref :  P208118
# 데이터 파일의 해당 id값 :  [<Question 66>]
# 데이터 파일의 our_ref :  P208118
# 데이터 파일 내 일치 our_ref 존재 :  66
# ===============
# 엑셀 파일의 our_ref :  P198229
# 데이터 파일의 해당 id값 :  [<Question 67>]
# 데이터 파일의 our_ref :  P198229
# 데이터 파일 내 일치 our_ref 존재 :  67
# ===============
# 엑셀 파일의 our_ref :  P198230
# 데이터 파일의 해당 id값 :  [<Question 68>]
# 데이터 파일의 our_ref :  P198230
# 데이터 파일 내 일치 our_ref 존재 :  68
# ===============
# 엑셀 파일의 our_ref :  P198236
# 데이터 파일의 해당 id값 :  [<Question 69>]
# 데이터 파일의 our_ref :  P198236
# 데이터 파일 내 일치 our_ref 존재 :  69
# ===============
# 엑셀 파일의 our_ref :  T198295
# 데이터 파일의 해당 id값 :  [<Question 70>]
# 데이터 파일의 our_ref :  T198295
# 데이터 파일 내 일치 our_ref 존재 :  70
# ===============
# 엑셀 파일의 our_ref :  T208080
# 데이터 파일의 해당 id값 :  [<Question 71>]
# 데이터 파일의 our_ref :  T208080
# 데이터 파일 내 일치 our_ref 존재 :  71
# ===============
# 엑셀 파일의 our_ref :  P198237
# 데이터 파일의 해당 id값 :  [<Question 72>]
# 데이터 파일의 our_ref :  P198237
# 데이터 파일 내 일치 our_ref 존재 :  72
# ===============
# 엑셀 파일의 our_ref :  P198246
# 데이터 파일의 해당 id값 :  [<Question 73>]
# 데이터 파일의 our_ref :  P198246
# 데이터 파일 내 일치 our_ref 존재 :  73
# ===============
# 엑셀 파일의 our_ref :  P198245
# 데이터 파일의 해당 id값 :  [<Question 74>]
# 데이터 파일의 our_ref :  P198245
# 데이터 파일 내 일치 our_ref 존재 :  74
# ===============
# 엑셀 파일의 our_ref :  P198247
# 데이터 파일의 해당 id값 :  [<Question 75>]
# 데이터 파일의 our_ref :  P198247
# 데이터 파일 내 일치 our_ref 존재 :  75
# ===============
# 엑셀 파일의 our_ref :  T198401
# 데이터 파일의 해당 id값 :  [<Question 76>]
# 데이터 파일의 our_ref :  T198401
# 데이터 파일 내 일치 our_ref 존재 :  76
# ===============
# 엑셀 파일의 our_ref :  T198402
# 데이터 파일의 해당 id값 :  [<Question 77>]
# 데이터 파일의 our_ref :  T198402
# 데이터 파일 내 일치 our_ref 존재 :  77
# ===============
# 엑셀 파일의 our_ref :  T198405
# 데이터 파일의 해당 id값 :  [<Question 78>]
# 데이터 파일의 our_ref :  T198405
# 데이터 파일 내 일치 our_ref 존재 :  78
# ===============
# 엑셀 파일의 our_ref :  P198240
# 데이터 파일의 해당 id값 :  [<Question 79>]
# 데이터 파일의 our_ref :  P198240
# 데이터 파일 내 일치 our_ref 존재 :  79
# ===============
# 엑셀 파일의 our_ref :  T208086
# 데이터 파일의 해당 id값 :  [<Question 80>]
# 데이터 파일의 our_ref :  T208086
# 데이터 파일 내 일치 our_ref 존재 :  80
# ===============
# 엑셀 파일의 our_ref :  T198184
# 데이터 파일의 해당 id값 :  [<Question 81>]
# 데이터 파일의 our_ref :  T198184
# 데이터 파일 내 일치 our_ref 존재 :  81
# ===============
# 엑셀 파일의 our_ref :  T198303
# 데이터 파일의 해당 id값 :  [<Question 82>]
# 데이터 파일의 our_ref :  T198303
# 데이터 파일 내 일치 our_ref 존재 :  82
# ===============
# 엑셀 파일의 our_ref :  T198305
# 데이터 파일의 해당 id값 :  [<Question 83>]
# 데이터 파일의 our_ref :  T198305
# 데이터 파일 내 일치 our_ref 존재 :  83
# ===============
# 엑셀 파일의 our_ref :  T198314
# 데이터 파일의 해당 id값 :  [<Question 84>]
# 데이터 파일의 our_ref :  T198314
# 데이터 파일 내 일치 our_ref 존재 :  84
# ===============
# 엑셀 파일의 our_ref :  P198344
# 데이터 파일의 해당 id값 :  [<Question 85>]
# 데이터 파일의 our_ref :  P198344
# 데이터 파일 내 일치 our_ref 존재 :  85
# ===============
# 엑셀 파일의 our_ref :  T198410
# 데이터 파일의 해당 id값 :  [<Question 86>]
# 데이터 파일의 our_ref :  T198410
# 데이터 파일 내 일치 our_ref 존재 :  86
# ===============
# 엑셀 파일의 our_ref :  T198411
# 데이터 파일의 해당 id값 :  [<Question 87>]
# 데이터 파일의 our_ref :  T198411
# 데이터 파일 내 일치 our_ref 존재 :  87
# ===============
# 엑셀 파일의 our_ref :  T198313
# 데이터 파일의 해당 id값 :  [<Question 88>]
# 데이터 파일의 our_ref :  T198313
# 데이터 파일 내 일치 our_ref 존재 :  88
# ===============
# 엑셀 파일의 our_ref :  D198029
# 데이터 파일의 해당 id값 :  [<Question 89>]
# 데이터 파일의 our_ref :  D198029
# 데이터 파일 내 일치 our_ref 존재 :  89
# ===============
# 엑셀 파일의 our_ref :  T208050
# 데이터 파일의 해당 id값 :  [<Question 90>]
# 데이터 파일의 our_ref :  T208050
# 데이터 파일 내 일치 our_ref 존재 :  90
# ===============
# 엑셀 파일의 our_ref :  T208051
# 데이터 파일의 해당 id값 :  [<Question 91>]
# 데이터 파일의 our_ref :  T208051
# 데이터 파일 내 일치 our_ref 존재 :  91
# ===============
# 엑셀 파일의 our_ref :  P198365
# 데이터 파일의 해당 id값 :  [<Question 92>]
# 데이터 파일의 our_ref :  P198365
# 데이터 파일 내 일치 our_ref 존재 :  92
# ===============
# 엑셀 파일의 our_ref :  T198183
# 데이터 파일의 해당 id값 :  [<Question 93>]
# 데이터 파일의 our_ref :  T198183
# 데이터 파일 내 일치 our_ref 존재 :  93
# ===============
# 엑셀 파일의 our_ref :  T198185
# 데이터 파일의 해당 id값 :  [<Question 94>]
# 데이터 파일의 our_ref :  T198185
# 데이터 파일 내 일치 our_ref 존재 :  94
# ===============
# 엑셀 파일의 our_ref :  P208005
# 데이터 파일의 해당 id값 :  [<Question 95>]
# 데이터 파일의 our_ref :  P208005
# 데이터 파일 내 일치 our_ref 존재 :  95
# ===============
# 엑셀 파일의 our_ref :  P198144
# 데이터 파일의 해당 id값 :  [<Question 96>]
# 데이터 파일의 our_ref :  P198144
# 데이터 파일 내 일치 our_ref 존재 :  96
# ===============
# 엑셀 파일의 our_ref :  P198145
# 데이터 파일의 해당 id값 :  [<Question 97>]
# 데이터 파일의 our_ref :  P198145
# 데이터 파일 내 일치 our_ref 존재 :  97
# ===============
# 엑셀 파일의 our_ref :  P198146
# 데이터 파일의 해당 id값 :  [<Question 98>]
# 데이터 파일의 our_ref :  P198146
# 데이터 파일 내 일치 our_ref 존재 :  98
# ===============
# 엑셀 파일의 our_ref :  P198147
# 데이터 파일의 해당 id값 :  [<Question 99>]
# 데이터 파일의 our_ref :  P198147
# 데이터 파일 내 일치 our_ref 존재 :  99
# ===============
# 엑셀 파일의 our_ref :  T198316
# 데이터 파일의 해당 id값 :  [<Question 100>]
# 데이터 파일의 our_ref :  T198316
# 데이터 파일 내 일치 our_ref 존재 :  100
# ===============
# 엑셀 파일의 our_ref :  T198396
# 데이터 파일의 해당 id값 :  [<Question 101>]
# 데이터 파일의 our_ref :  T198396
# 데이터 파일 내 일치 our_ref 존재 :  101
# ===============
# 엑셀 파일의 our_ref :  T198397
# 데이터 파일의 해당 id값 :  [<Question 102>]
# 데이터 파일의 our_ref :  T198397
# 데이터 파일 내 일치 our_ref 존재 :  102
# ===============
# 엑셀 파일의 our_ref :  T198398
# 데이터 파일의 해당 id값 :  [<Question 103>]
# 데이터 파일의 our_ref :  T198398
# 데이터 파일 내 일치 our_ref 존재 :  103
# ===============
# 엑셀 파일의 our_ref :  P198131
# 데이터 파일의 해당 id값 :  [<Question 104>]
# 데이터 파일의 our_ref :  P198131
# 데이터 파일 내 일치 our_ref 존재 :  104
# ===============
# 엑셀 파일의 our_ref :  T198315
# 데이터 파일의 해당 id값 :  [<Question 105>]
# 데이터 파일의 our_ref :  T198315
# 데이터 파일 내 일치 our_ref 존재 :  105
# ===============
# 엑셀 파일의 our_ref :  T198399
# 데이터 파일의 해당 id값 :  [<Question 106>]
# 데이터 파일의 our_ref :  T198399
# 데이터 파일 내 일치 our_ref 존재 :  106
# ===============
# 엑셀 파일의 our_ref :  P198132
# 데이터 파일의 해당 id값 :  [<Question 107>]
# 데이터 파일의 our_ref :  P198132
# 데이터 파일 내 일치 our_ref 존재 :  107
# ===============
# 엑셀 파일의 our_ref :  T198191
# 데이터 파일의 해당 id값 :  [<Question 108>]
# 데이터 파일의 our_ref :  T198191
# 데이터 파일 내 일치 our_ref 존재 :  108
# ===============
# 엑셀 파일의 our_ref :  T198192
# 데이터 파일의 해당 id값 :  [<Question 109>]
# 데이터 파일의 our_ref :  T198192
# 데이터 파일 내 일치 our_ref 존재 :  109
# ===============
# 엑셀 파일의 our_ref :  P198100
# 데이터 파일의 해당 id값 :  [<Question 110>]
# 데이터 파일의 our_ref :  P198100
# 데이터 파일 내 일치 our_ref 존재 :  110
# ===============
# 엑셀 파일의 our_ref :  P198266
# 데이터 파일의 해당 id값 :  [<Question 111>]
# 데이터 파일의 our_ref :  P198266
# 데이터 파일 내 일치 our_ref 존재 :  111
# ===============
# 엑셀 파일의 our_ref :  D198007
# 데이터 파일의 해당 id값 :  [<Question 112>]
# 데이터 파일의 our_ref :  D198007
# 데이터 파일 내 일치 our_ref 존재 :  112
# ===============
# 엑셀 파일의 our_ref :  T208002
# 데이터 파일의 해당 id값 :  [<Question 113>]
# 데이터 파일의 our_ref :  T208002
# 데이터 파일 내 일치 our_ref 존재 :  113
# ===============
# 엑셀 파일의 our_ref :  D198024
# 데이터 파일의 해당 id값 :  [<Question 114>]
# 데이터 파일의 our_ref :  D198024
# 데이터 파일 내 일치 our_ref 존재 :  114
# ===============
# 엑셀 파일의 our_ref :  P198002
# 데이터 파일의 해당 id값 :  [<Question 115>]
# 데이터 파일의 our_ref :  P198002
# 데이터 파일 내 일치 our_ref 존재 :  115
# ===============
# 엑셀 파일의 our_ref :  P198005
# 데이터 파일의 해당 id값 :  [<Question 116>]
# 데이터 파일의 our_ref :  P198005
# 데이터 파일 내 일치 our_ref 존재 :  116
# ===============
# 엑셀 파일의 our_ref :  P198008
# 데이터 파일의 해당 id값 :  [<Question 117>]
# 데이터 파일의 our_ref :  P198008
# 데이터 파일 내 일치 our_ref 존재 :  117
# ===============
# 엑셀 파일의 our_ref :  P198009
# 데이터 파일의 해당 id값 :  [<Question 118>]
# 데이터 파일의 our_ref :  P198009
# 데이터 파일 내 일치 our_ref 존재 :  118
# ===============
# 엑셀 파일의 our_ref :  P198010
# 데이터 파일의 해당 id값 :  [<Question 119>]
# 데이터 파일의 our_ref :  P198010
# 데이터 파일 내 일치 our_ref 존재 :  119
# ===============
# 엑셀 파일의 our_ref :  P198011
# 데이터 파일의 해당 id값 :  [<Question 120>]
# 데이터 파일의 our_ref :  P198011
# 데이터 파일 내 일치 our_ref 존재 :  120
# ===============
# 엑셀 파일의 our_ref :  T198059
# 데이터 파일의 해당 id값 :  [<Question 121>]
# 데이터 파일의 our_ref :  T198059
# 데이터 파일 내 일치 our_ref 존재 :  121
# ===============
# 엑셀 파일의 our_ref :  P198273
# 데이터 파일의 해당 id값 :  [<Question 122>]
# 데이터 파일의 our_ref :  P198273
# 데이터 파일 내 일치 our_ref 존재 :  122
# ===============
# 엑셀 파일의 our_ref :  P198274
# 데이터 파일의 해당 id값 :  [<Question 123>]
# 데이터 파일의 our_ref :  P198274
# 데이터 파일 내 일치 our_ref 존재 :  123
# ===============
# 엑셀 파일의 our_ref :  P198019
# 데이터 파일의 해당 id값 :  [<Question 124>]
# 데이터 파일의 our_ref :  P198019
# 데이터 파일 내 일치 our_ref 존재 :  124
# ===============
# 엑셀 파일의 our_ref :  P198021
# 데이터 파일의 해당 id값 :  [<Question 125>]
# 데이터 파일의 our_ref :  P198021
# 데이터 파일 내 일치 our_ref 존재 :  125
# ===============
# 엑셀 파일의 our_ref :  P198022
# 데이터 파일의 해당 id값 :  [<Question 126>]
# 데이터 파일의 our_ref :  P198022
# 데이터 파일 내 일치 our_ref 존재 :  126
# ===============
# 엑셀 파일의 our_ref :  P198141
# 데이터 파일의 해당 id값 :  [<Question 127>]
# 데이터 파일의 our_ref :  P198141
# 데이터 파일 내 일치 our_ref 존재 :  127
# ===============
# 엑셀 파일의 our_ref :  T198017
# 데이터 파일의 해당 id값 :  [<Question 128>]
# 데이터 파일의 our_ref :  T198017
# 데이터 파일 내 일치 our_ref 존재 :  128
# ===============
# 엑셀 파일의 our_ref :  P198142
# 데이터 파일의 해당 id값 :  [<Question 129>]
# 데이터 파일의 our_ref :  P198142
# 데이터 파일 내 일치 our_ref 존재 :  129
# ===============
# 엑셀 파일의 our_ref :  P198263
# 데이터 파일의 해당 id값 :  [<Question 130>]
# 데이터 파일의 our_ref :  P198263
# 데이터 파일 내 일치 our_ref 존재 :  130
# ===============
# 엑셀 파일의 our_ref :  P198264
# 데이터 파일의 해당 id값 :  [<Question 131>]
# 데이터 파일의 our_ref :  P198264
# 데이터 파일 내 일치 our_ref 존재 :  131
# ===============
# 엑셀 파일의 our_ref :  P198265
# 데이터 파일의 해당 id값 :  [<Question 132>]
# 데이터 파일의 our_ref :  P198265
# 데이터 파일 내 일치 our_ref 존재 :  132
# ===============
# 엑셀 파일의 our_ref :  P198267
# 데이터 파일의 해당 id값 :  [<Question 133>]
# 데이터 파일의 our_ref :  P198267
# 데이터 파일 내 일치 our_ref 존재 :  133
# ===============
# 엑셀 파일의 our_ref :  P198268
# 데이터 파일의 해당 id값 :  [<Question 134>]
# 데이터 파일의 our_ref :  P198268
# 데이터 파일 내 일치 our_ref 존재 :  134
# ===============
# 엑셀 파일의 our_ref :  T208007
# 데이터 파일의 해당 id값 :  [<Question 135>]
# 데이터 파일의 our_ref :  T208007
# 데이터 파일 내 일치 our_ref 존재 :  135
# ===============
# 엑셀 파일의 our_ref :  T208009
# 데이터 파일의 해당 id값 :  [<Question 136>]
# 데이터 파일의 our_ref :  T208009
# 데이터 파일 내 일치 our_ref 존재 :  136
# ===============
# 엑셀 파일의 our_ref :  P198004
# 데이터 파일의 해당 id값 :  [<Question 137>]
# 데이터 파일의 our_ref :  P198004
# 데이터 파일 내 일치 our_ref 존재 :  137
# ===============
# 엑셀 파일의 our_ref :  T198196
# 데이터 파일의 해당 id값 :  [<Question 138>]
# 데이터 파일의 our_ref :  T198196
# 데이터 파일 내 일치 our_ref 존재 :  138
# ===============
# 엑셀 파일의 our_ref :  T198204
# 데이터 파일의 해당 id값 :  [<Question 139>]
# 데이터 파일의 our_ref :  T198204
# 데이터 파일 내 일치 our_ref 존재 :  139
# ===============
# 엑셀 파일의 our_ref :  T198210
# 데이터 파일의 해당 id값 :  [<Question 140>]
# 데이터 파일의 our_ref :  T198210
# 데이터 파일 내 일치 our_ref 존재 :  140
# ===============
# 엑셀 파일의 our_ref :  T198211
# 데이터 파일의 해당 id값 :  [<Question 141>]
# 데이터 파일의 our_ref :  T198211
# 데이터 파일 내 일치 our_ref 존재 :  141
# ===============
# 엑셀 파일의 our_ref :  P198047
# 데이터 파일의 해당 id값 :  [<Question 142>]
# 데이터 파일의 our_ref :  P198047
# 데이터 파일 내 일치 our_ref 존재 :  142
# ===============
# 엑셀 파일의 our_ref :  P198160
# 데이터 파일의 해당 id값 :  [<Question 143>]
# 데이터 파일의 our_ref :  P198160
# 데이터 파일 내 일치 our_ref 존재 :  143
# ===============
# 엑셀 파일의 our_ref :  P198020
# 데이터 파일의 해당 id값 :  [<Question 144>]
# 데이터 파일의 our_ref :  P198020
# 데이터 파일 내 일치 our_ref 존재 :  144
# ===============
# 엑셀 파일의 our_ref :  P198023
# 데이터 파일의 해당 id값 :  [<Question 145>]
# 데이터 파일의 our_ref :  P198023
# 데이터 파일 내 일치 our_ref 존재 :  145
# ===============
# 엑셀 파일의 our_ref :  T198203
# 데이터 파일의 해당 id값 :  [<Question 146>]
# 데이터 파일의 our_ref :  T198203
# 데이터 파일 내 일치 our_ref 존재 :  146
# ===============
# 엑셀 파일의 our_ref :  T198208
# 데이터 파일의 해당 id값 :  [<Question 147>]
# 데이터 파일의 our_ref :  T198208
# 데이터 파일 내 일치 our_ref 존재 :  147
# ===============
# 엑셀 파일의 our_ref :  T198209
# 데이터 파일의 해당 id값 :  [<Question 148>]
# 데이터 파일의 our_ref :  T198209
# 데이터 파일 내 일치 our_ref 존재 :  148
# ===============
# 엑셀 파일의 our_ref :  T198212
# 데이터 파일의 해당 id값 :  [<Question 149>]
# 데이터 파일의 our_ref :  T198212
# 데이터 파일 내 일치 our_ref 존재 :  149
# ===============
# 엑셀 파일의 our_ref :  T198045
# 데이터 파일의 해당 id값 :  [<Question 150>]
# 데이터 파일의 our_ref :  T198045
# 데이터 파일 내 일치 our_ref 존재 :  150
# ===============
# 엑셀 파일의 our_ref :  P198280
# 데이터 파일의 해당 id값 :  [<Question 151>]
# 데이터 파일의 our_ref :  P198280
# 데이터 파일 내 일치 our_ref 존재 :  151
# ===============
# 엑셀 파일의 our_ref :  P198166
# 데이터 파일의 해당 id값 :  [<Question 152>]
# 데이터 파일의 our_ref :  P198166
# 데이터 파일 내 일치 our_ref 존재 :  152
# ===============
# 엑셀 파일의 our_ref :  P198169
# 데이터 파일의 해당 id값 :  [<Question 153>]
# 데이터 파일의 our_ref :  P198169
# 데이터 파일 내 일치 our_ref 존재 :  153
# ===============
# 엑셀 파일의 our_ref :  P198276
# 데이터 파일의 해당 id값 :  [<Question 154>]
# 데이터 파일의 our_ref :  P198276
# 데이터 파일 내 일치 our_ref 존재 :  154
# ===============
# 엑셀 파일의 our_ref :  T208087
# 데이터 파일의 해당 id값 :  [<Question 155>]
# 데이터 파일의 our_ref :  T208087
# 데이터 파일 내 일치 our_ref 존재 :  155
# ===============
# 엑셀 파일의 our_ref :  P198279
# 데이터 파일의 해당 id값 :  [<Question 156>]
# 데이터 파일의 our_ref :  P198279
# 데이터 파일 내 일치 our_ref 존재 :  156
# ===============
# 엑셀 파일의 our_ref :  P198282
# 데이터 파일의 해당 id값 :  [<Question 157>]
# 데이터 파일의 our_ref :  P198282
# 데이터 파일 내 일치 our_ref 존재 :  157
# ===============
# 엑셀 파일의 our_ref :  P208018
# 데이터 파일의 해당 id값 :  [<Question 158>]
# 데이터 파일의 our_ref :  P208018
# 데이터 파일 내 일치 our_ref 존재 :  158
# ===============
# 엑셀 파일의 our_ref :  T198018
# 데이터 파일의 해당 id값 :  [<Question 159>]
# 데이터 파일의 our_ref :  T198018
# 데이터 파일 내 일치 our_ref 존재 :  159
# ===============
# 엑셀 파일의 our_ref :  T198021
# 데이터 파일의 해당 id값 :  [<Question 160>]
# 데이터 파일의 our_ref :  T198021
# 데이터 파일 내 일치 our_ref 존재 :  160
# ===============
# 엑셀 파일의 our_ref :  T198024
# 데이터 파일의 해당 id값 :  [<Question 161>]
# 데이터 파일의 our_ref :  T198024
# 데이터 파일 내 일치 our_ref 존재 :  161
# ===============
# 엑셀 파일의 our_ref :  P198161
# 데이터 파일의 해당 id값 :  [<Question 162>]
# 데이터 파일의 our_ref :  P198161
# 데이터 파일 내 일치 our_ref 존재 :  162
# ===============
# 엑셀 파일의 our_ref :  P198162
# 데이터 파일의 해당 id값 :  [<Question 163>]
# 데이터 파일의 our_ref :  P198162
# 데이터 파일 내 일치 our_ref 존재 :  163
# ===============
# 엑셀 파일의 our_ref :  P198038
# 데이터 파일의 해당 id값 :  [<Question 164>]
# 데이터 파일의 our_ref :  P198038
# 데이터 파일 내 일치 our_ref 존재 :  164
# ===============
# 엑셀 파일의 our_ref :  P198040
# 데이터 파일의 해당 id값 :  [<Question 165>]
# 데이터 파일의 our_ref :  P198040
# 데이터 파일 내 일치 our_ref 존재 :  165
# ===============
# 엑셀 파일의 our_ref :  P198289
# 데이터 파일의 해당 id값 :  [<Question 166>]
# 데이터 파일의 our_ref :  P198289
# 데이터 파일 내 일치 our_ref 존재 :  166
# ===============
# 엑셀 파일의 our_ref :  P198294
# 데이터 파일의 해당 id값 :  [<Question 167>]
# 데이터 파일의 our_ref :  P198294
# 데이터 파일 내 일치 our_ref 존재 :  167
# ===============
# 엑셀 파일의 our_ref :  P198295
# 데이터 파일의 해당 id값 :  [<Question 168>]
# 데이터 파일의 our_ref :  P198295
# 데이터 파일 내 일치 our_ref 존재 :  168
# ===============
# 엑셀 파일의 our_ref :  T198328
# 데이터 파일의 해당 id값 :  [<Question 169>]
# 데이터 파일의 our_ref :  T198328
# 데이터 파일 내 일치 our_ref 존재 :  169
# ===============
# 엑셀 파일의 our_ref :  T198329
# 데이터 파일의 해당 id값 :  [<Question 170>]
# 데이터 파일의 our_ref :  T198329
# 데이터 파일 내 일치 our_ref 존재 :  170
# ===============
# 엑셀 파일의 our_ref :  T198049
# 데이터 파일의 해당 id값 :  [<Question 171>]
# 데이터 파일의 our_ref :  T198049
# 데이터 파일 내 일치 our_ref 존재 :  171
# ===============
# 엑셀 파일의 our_ref :  P198290
# 데이터 파일의 해당 id값 :  [<Question 172>]
# 데이터 파일의 our_ref :  P198290
# 데이터 파일 내 일치 our_ref 존재 :  172
# ===============
# 엑셀 파일의 our_ref :  T208088
# 데이터 파일의 해당 id값 :  [<Question 173>]
# 데이터 파일의 our_ref :  T208088
# 데이터 파일 내 일치 our_ref 존재 :  173
# ===============
# 엑셀 파일의 our_ref :  T198027
# 데이터 파일의 해당 id값 :  [<Question 174>]
# 데이터 파일의 our_ref :  T198027
# 데이터 파일 내 일치 our_ref 존재 :  174
# ===============
# 엑셀 파일의 our_ref :  T198029
# 데이터 파일의 해당 id값 :  [<Question 175>]
# 데이터 파일의 our_ref :  T198029
# 데이터 파일 내 일치 our_ref 존재 :  175
# ===============
# 엑셀 파일의 our_ref :  T198053
# 데이터 파일의 해당 id값 :  [<Question 176>]
# 데이터 파일의 our_ref :  T198053
# 데이터 파일 내 일치 our_ref 존재 :  176
# ===============
# 엑셀 파일의 our_ref :  P198044
# 데이터 파일의 해당 id값 :  [<Question 177>]
# 데이터 파일의 our_ref :  P198044
# 데이터 파일 내 일치 our_ref 존재 :  177
# ===============
# 엑셀 파일의 our_ref :  T198047
# 데이터 파일의 해당 id값 :  [<Question 178>]
# 데이터 파일의 our_ref :  T198047
# 데이터 파일 내 일치 our_ref 존재 :  178
# ===============
# 엑셀 파일의 our_ref :  T198330
# 데이터 파일의 해당 id값 :  [<Question 179>]
# 데이터 파일의 our_ref :  T198330
# 데이터 파일 내 일치 our_ref 존재 :  179
# ===============
# 엑셀 파일의 our_ref :  D208020
# 데이터 파일의 해당 id값 :  [<Question 180>]
# 데이터 파일의 our_ref :  D208020
# 데이터 파일 내 일치 our_ref 존재 :  180
# ===============
# 엑셀 파일의 our_ref :  T208093
# 데이터 파일의 해당 id값 :  [<Question 181>]
# 데이터 파일의 our_ref :  T208093
# 데이터 파일 내 일치 our_ref 존재 :  181
# ===============
# 엑셀 파일의 our_ref :  D198009
# 데이터 파일의 해당 id값 :  [<Question 182>]
# 데이터 파일의 our_ref :  D198009
# 데이터 파일 내 일치 our_ref 존재 :  182
# ===============
# 엑셀 파일의 our_ref :  T198048
# 데이터 파일의 해당 id값 :  [<Question 183>]
# 데이터 파일의 our_ref :  T198048
# 데이터 파일 내 일치 our_ref 존재 :  183
# ===============
# 엑셀 파일의 our_ref :  T198050
# 데이터 파일의 해당 id값 :  [<Question 184>]
# 데이터 파일의 our_ref :  T198050
# 데이터 파일 내 일치 our_ref 존재 :  184
# ===============
# 엑셀 파일의 our_ref :  T198051
# 데이터 파일의 해당 id값 :  [<Question 185>]
# 데이터 파일의 our_ref :  T198051
# 데이터 파일 내 일치 our_ref 존재 :  185
# ===============
# 엑셀 파일의 our_ref :  T198060
# 데이터 파일의 해당 id값 :  [<Question 186>]
# 데이터 파일의 our_ref :  T198060
# 데이터 파일 내 일치 our_ref 존재 :  186
# ===============
# 엑셀 파일의 our_ref :  P198174
# 데이터 파일의 해당 id값 :  [<Question 187>]
# 데이터 파일의 our_ref :  P198174
# 데이터 파일 내 일치 our_ref 존재 :  187
# ===============
# 엑셀 파일의 our_ref :  T208092
# 데이터 파일의 해당 id값 :  [<Question 188>]
# 데이터 파일의 our_ref :  T208092
# 데이터 파일 내 일치 our_ref 존재 :  188
# ===============
# 엑셀 파일의 our_ref :  T198065
# 데이터 파일의 해당 id값 :  [<Question 189>]
# 데이터 파일의 our_ref :  T198065
# 데이터 파일 내 일치 our_ref 존재 :  189
# ===============
# 엑셀 파일의 our_ref :  T198066
# 데이터 파일의 해당 id값 :  [<Question 190>]
# 데이터 파일의 our_ref :  T198066
# 데이터 파일 내 일치 our_ref 존재 :  190
# ===============
# 엑셀 파일의 our_ref :  P198050
# 데이터 파일의 해당 id값 :  [<Question 191>]
# 데이터 파일의 our_ref :  P198050
# 데이터 파일 내 일치 our_ref 존재 :  191
# ===============
# 엑셀 파일의 our_ref :  T198084
# 데이터 파일의 해당 id값 :  [<Question 192>]
# 데이터 파일의 our_ref :  T198084
# 데이터 파일 내 일치 our_ref 존재 :  192
# ===============
# 엑셀 파일의 our_ref :  T198294
# 데이터 파일의 해당 id값 :  [<Question 193>]
# 데이터 파일의 our_ref :  T198294
# 데이터 파일 내 일치 our_ref 존재 :  193
# ===============
# 엑셀 파일의 our_ref :  T208106
# 데이터 파일의 해당 id값 :  [<Question 194>]
# 데이터 파일의 our_ref :  T208106
# 데이터 파일 내 일치 our_ref 존재 :  194
# ===============
# 엑셀 파일의 our_ref :  T198143
# 데이터 파일의 해당 id값 :  [<Question 195>]
# 데이터 파일의 our_ref :  T198143
# 데이터 파일 내 일치 our_ref 존재 :  195
# ===============
# 엑셀 파일의 our_ref :  T198073
# 데이터 파일의 해당 id값 :  [<Question 196>]
# 데이터 파일의 our_ref :  T198073
# 데이터 파일 내 일치 our_ref 존재 :  196
# ===============
# 엑셀 파일의 our_ref :  T198089
# 데이터 파일의 해당 id값 :  [<Question 197>]
# 데이터 파일의 our_ref :  T198089
# 데이터 파일 내 일치 our_ref 존재 :  197
# ===============
# 엑셀 파일의 our_ref :  T208400
# 데이터 파일의 해당 id값 :  [<Question 198>]
# 데이터 파일의 our_ref :  T208400
# 데이터 파일 내 일치 our_ref 존재 :  198
# ===============
# 엑셀 파일의 our_ref :  D198020
# 데이터 파일의 해당 id값 :  [<Question 199>]
# 데이터 파일의 our_ref :  D198020
# 데이터 파일 내 일치 our_ref 존재 :  199
# ===============
# 엑셀 파일의 our_ref :  T208095
# 데이터 파일의 해당 id값 :  [<Question 200>]
# 데이터 파일의 our_ref :  T208095
# 데이터 파일 내 일치 our_ref 존재 :  200
# ===============
# 엑셀 파일의 our_ref :  T208096
# 데이터 파일의 해당 id값 :  [<Question 201>]
# 데이터 파일의 our_ref :  T208096
# 데이터 파일 내 일치 our_ref 존재 :  201
# ===============
# 엑셀 파일의 our_ref :  T198091
# 데이터 파일의 해당 id값 :  [<Question 202>]
# 데이터 파일의 our_ref :  T198091
# 데이터 파일 내 일치 our_ref 존재 :  202
# ===============
# 엑셀 파일의 our_ref :  T198067
# 데이터 파일의 해당 id값 :  [<Question 203>]
# 데이터 파일의 our_ref :  T198067
# 데이터 파일 내 일치 our_ref 존재 :  203
# ===============
# 엑셀 파일의 our_ref :  P198048
# 데이터 파일의 해당 id값 :  [<Question 204>]
# 데이터 파일의 our_ref :  P198048
# 데이터 파일 내 일치 our_ref 존재 :  204
# ===============
# 엑셀 파일의 our_ref :  P198049
# 데이터 파일의 해당 id값 :  [<Question 205>]
# 데이터 파일의 our_ref :  P198049
# 데이터 파일 내 일치 our_ref 존재 :  205
# ===============
# 엑셀 파일의 our_ref :  T198071
# 데이터 파일의 해당 id값 :  [<Question 206>]
# 데이터 파일의 our_ref :  T198071
# 데이터 파일 내 일치 our_ref 존재 :  206
# ===============
# 엑셀 파일의 our_ref :  T198096
# 데이터 파일의 해당 id값 :  [<Question 207>]
# 데이터 파일의 our_ref :  T198096
# 데이터 파일 내 일치 our_ref 존재 :  207
# ===============
# 엑셀 파일의 our_ref :  T198099
# 데이터 파일의 해당 id값 :  [<Question 208>]
# 데이터 파일의 our_ref :  T198099
# 데이터 파일 내 일치 our_ref 존재 :  208
# ===============
# 엑셀 파일의 our_ref :  P208032
# 데이터 파일의 해당 id값 :  [<Question 209>]
# 데이터 파일의 our_ref :  P208032
# 데이터 파일 내 일치 our_ref 존재 :  209
# ===============
# 엑셀 파일의 our_ref :  P198051
# 데이터 파일의 해당 id값 :  [<Question 210>]
# 데이터 파일의 our_ref :  P198051
# 데이터 파일 내 일치 our_ref 존재 :  210
# ===============
# 엑셀 파일의 our_ref :  T198077
# 데이터 파일의 해당 id값 :  [<Question 211>]
# 데이터 파일의 our_ref :  T198077
# 데이터 파일 내 일치 our_ref 존재 :  211
# ===============
# 엑셀 파일의 our_ref :  T198337
# 데이터 파일의 해당 id값 :  [<Question 212>]
# 데이터 파일의 our_ref :  T198337
# 데이터 파일 내 일치 our_ref 존재 :  212
# ===============
# 엑셀 파일의 our_ref :  P208034
# 데이터 파일의 해당 id값 :  [<Question 213>]
# 데이터 파일의 our_ref :  P208034
# 데이터 파일 내 일치 our_ref 존재 :  213
# ===============
# 엑셀 파일의 our_ref :  P208236
# 데이터 파일의 해당 id값 :  [<Question 214>]
# 데이터 파일의 our_ref :  P208236
# 데이터 파일 내 일치 our_ref 존재 :  214
# ===============
# 엑셀 파일의 our_ref :  T198217
# 데이터 파일의 해당 id값 :  [<Question 215>]
# 데이터 파일의 our_ref :  T198217
# 데이터 파일 내 일치 our_ref 존재 :  215
# ===============
# 엑셀 파일의 our_ref :  T198218
# 데이터 파일의 해당 id값 :  [<Question 216>]
# 데이터 파일의 our_ref :  T198218
# 데이터 파일 내 일치 our_ref 존재 :  216
# ===============
# 엑셀 파일의 our_ref :  T198215
# 데이터 파일의 해당 id값 :  [<Question 217>]
# 데이터 파일의 our_ref :  T198215
# 데이터 파일 내 일치 our_ref 존재 :  217
# ===============
# 엑셀 파일의 our_ref :  D198018
# 데이터 파일의 해당 id값 :  [<Question 218>]
# 데이터 파일의 our_ref :  D198018
# 데이터 파일 내 일치 our_ref 존재 :  218
# ===============
# 엑셀 파일의 our_ref :  T198093
# 데이터 파일의 해당 id값 :  [<Question 219>]
# 데이터 파일의 our_ref :  T198093
# 데이터 파일 내 일치 our_ref 존재 :  219
# ===============
# 엑셀 파일의 our_ref :  T198333
# 데이터 파일의 해당 id값 :  [<Question 220>]
# 데이터 파일의 our_ref :  T198333
# 데이터 파일 내 일치 our_ref 존재 :  220
# ===============
# 엑셀 파일의 our_ref :  T198098
# 데이터 파일의 해당 id값 :  [<Question 221>]
# 데이터 파일의 our_ref :  T198098
# 데이터 파일 내 일치 our_ref 존재 :  221
# ===============
# 엑셀 파일의 our_ref :  P208038
# 데이터 파일의 해당 id값 :  [<Question 222>]
# 데이터 파일의 our_ref :  P208038
# 데이터 파일 내 일치 our_ref 존재 :  222
# ===============
# 엑셀 파일의 our_ref :  T198078
# 데이터 파일의 해당 id값 :  [<Question 223>]
# 데이터 파일의 our_ref :  T198078
# 데이터 파일 내 일치 our_ref 존재 :  223
# ===============
# 엑셀 파일의 our_ref :  T198079
# 데이터 파일의 해당 id값 :  [<Question 224>]
# 데이터 파일의 our_ref :  T198079
# 데이터 파일 내 일치 our_ref 존재 :  224
# ===============
# 엑셀 파일의 our_ref :  T198080
# 데이터 파일의 해당 id값 :  [<Question 225>]
# 데이터 파일의 our_ref :  T198080
# 데이터 파일 내 일치 our_ref 존재 :  225
# ===============
# 엑셀 파일의 our_ref :  T198081
# 데이터 파일의 해당 id값 :  [<Question 226>]
# 데이터 파일의 our_ref :  T198081
# 데이터 파일 내 일치 our_ref 존재 :  226
# ===============
# 엑셀 파일의 our_ref :  T198082
# 데이터 파일의 해당 id값 :  [<Question 227>]
# 데이터 파일의 our_ref :  T198082
# 데이터 파일 내 일치 our_ref 존재 :  227
# ===============
# 엑셀 파일의 our_ref :  T198083
# 데이터 파일의 해당 id값 :  [<Question 228>]
# 데이터 파일의 our_ref :  T198083
# 데이터 파일 내 일치 our_ref 존재 :  228
# ===============
# 엑셀 파일의 our_ref :  D198019
# 데이터 파일의 해당 id값 :  [<Question 229>]
# 데이터 파일의 our_ref :  D198019
# 데이터 파일 내 일치 our_ref 존재 :  229
# ===============
# 엑셀 파일의 our_ref :  T198092
# 데이터 파일의 해당 id값 :  [<Question 230>]
# 데이터 파일의 our_ref :  T198092
# 데이터 파일 내 일치 our_ref 존재 :  230
# ===============
# 엑셀 파일의 our_ref :  T198097
# 데이터 파일의 해당 id값 :  [<Question 231>]
# 데이터 파일의 our_ref :  T198097
# 데이터 파일 내 일치 our_ref 존재 :  231
# ===============
# 엑셀 파일의 our_ref :  P198060
# 데이터 파일의 해당 id값 :  [<Question 232>]
# 데이터 파일의 our_ref :  P198060
# 데이터 파일 내 일치 our_ref 존재 :  232
# ===============
# 엑셀 파일의 our_ref :  P198062
# 데이터 파일의 해당 id값 :  [<Question 233>]
# 데이터 파일의 our_ref :  P198062
# 데이터 파일 내 일치 our_ref 존재 :  233
# ===============
# 엑셀 파일의 our_ref :  P198064
# 데이터 파일의 해당 id값 :  [<Question 234>]
# 데이터 파일의 our_ref :  P198064
# 데이터 파일 내 일치 our_ref 존재 :  234
# ===============
# 엑셀 파일의 our_ref :  T198230
# 데이터 파일의 해당 id값 :  [<Question 235>]
# 데이터 파일의 our_ref :  T198230
# 데이터 파일 내 일치 our_ref 존재 :  235
# ===============
# 엑셀 파일의 our_ref :  T198231
# 데이터 파일의 해당 id값 :  [<Question 236>]
# 데이터 파일의 our_ref :  T198231
# 데이터 파일 내 일치 our_ref 존재 :  236
# ===============
# 엑셀 파일의 our_ref :  P198311
# 데이터 파일의 해당 id값 :  [<Question 237>]
# 데이터 파일의 our_ref :  P198311
# 데이터 파일 내 일치 our_ref 존재 :  237
# ===============
# 엑셀 파일의 our_ref :  P198312
# 데이터 파일의 해당 id값 :  [<Question 238>]
# 데이터 파일의 our_ref :  P198312
# 데이터 파일 내 일치 our_ref 존재 :  238
# ===============
# 엑셀 파일의 our_ref :  T198338
# 데이터 파일의 해당 id값 :  [<Question 239>]
# 데이터 파일의 our_ref :  T198338
# 데이터 파일 내 일치 our_ref 존재 :  239
# ===============
# 엑셀 파일의 our_ref :  T198339
# 데이터 파일의 해당 id값 :  [<Question 240>]
# 데이터 파일의 our_ref :  T198339
# 데이터 파일 내 일치 our_ref 존재 :  240
# ===============
# 엑셀 파일의 our_ref :  P198314
# 데이터 파일의 해당 id값 :  [<Question 241>]
# 데이터 파일의 our_ref :  P198314
# 데이터 파일 내 일치 our_ref 존재 :  241
# ===============
# 엑셀 파일의 our_ref :  P198315
# 데이터 파일의 해당 id값 :  [<Question 242>]
# 데이터 파일의 our_ref :  P198315
# 데이터 파일 내 일치 our_ref 존재 :  242
# ===============
# 엑셀 파일의 our_ref :  P198193
# 데이터 파일의 해당 id값 :  [<Question 243>]
# 데이터 파일의 our_ref :  P198193
# 데이터 파일 내 일치 our_ref 존재 :  243
# ===============
# 엑셀 파일의 our_ref :  T198229
# 데이터 파일의 해당 id값 :  [<Question 244>]
# 데이터 파일의 our_ref :  T198229
# 데이터 파일 내 일치 our_ref 존재 :  244
# ===============
# 엑셀 파일의 our_ref :  P198195
# 데이터 파일의 해당 id값 :  [<Question 245>]
# 데이터 파일의 our_ref :  P198195
# 데이터 파일 내 일치 our_ref 존재 :  245
# ===============
# 엑셀 파일의 our_ref :  T198238
# 데이터 파일의 해당 id값 :  [<Question 246>]
# 데이터 파일의 our_ref :  T198238
# 데이터 파일 내 일치 our_ref 존재 :  246
# ===============
# 엑셀 파일의 our_ref :  D198054
# 데이터 파일의 해당 id값 :  [<Question 247>]
# 데이터 파일의 our_ref :  D198054
# 데이터 파일 내 일치 our_ref 존재 :  247
# ===============
# 엑셀 파일의 our_ref :  P198194
# 데이터 파일의 해당 id값 :  [<Question 248>]
# 데이터 파일의 our_ref :  P198194
# 데이터 파일 내 일치 our_ref 존재 :  248
# ===============
# 엑셀 파일의 our_ref :  P198196
# 데이터 파일의 해당 id값 :  [<Question 249>]
# 데이터 파일의 our_ref :  P198196
# 데이터 파일 내 일치 our_ref 존재 :  249
# ===============
# 엑셀 파일의 our_ref :  P198197
# 데이터 파일의 해당 id값 :  [<Question 250>]
# 데이터 파일의 our_ref :  P198197
# 데이터 파일 내 일치 our_ref 존재 :  250
# ===============
# 엑셀 파일의 our_ref :  T198367
# 데이터 파일의 해당 id값 :  [<Question 251>]
# 데이터 파일의 our_ref :  T198367
# 데이터 파일 내 일치 our_ref 존재 :  251
# ===============
# 엑셀 파일의 our_ref :  P198069
# 데이터 파일의 해당 id값 :  [<Question 252>]
# 데이터 파일의 our_ref :  P198069
# 데이터 파일 내 일치 our_ref 존재 :  252
# ===============
# 엑셀 파일의 our_ref :  P198070
# 데이터 파일의 해당 id값 :  [<Question 253>]
# 데이터 파일의 our_ref :  P198070
# 데이터 파일 내 일치 our_ref 존재 :  253
# ===============
# 엑셀 파일의 our_ref :  P198072
# 데이터 파일의 해당 id값 :  [<Question 254>]
# 데이터 파일의 our_ref :  P198072
# 데이터 파일 내 일치 our_ref 존재 :  254
# ===============
# 엑셀 파일의 our_ref :  P198073
# 데이터 파일의 해당 id값 :  [<Question 255>]
# 데이터 파일의 our_ref :  P198073
# 데이터 파일 내 일치 our_ref 존재 :  255
# ===============
# 엑셀 파일의 our_ref :  P198074
# 데이터 파일의 해당 id값 :  [<Question 256>]
# 데이터 파일의 our_ref :  P198074
# 데이터 파일 내 일치 our_ref 존재 :  256
# ===============
# 엑셀 파일의 our_ref :  T198121
# 데이터 파일의 해당 id값 :  [<Question 257>]
# 데이터 파일의 our_ref :  T198121
# 데이터 파일 내 일치 our_ref 존재 :  257
# ===============
# 엑셀 파일의 our_ref :  T198122
# 데이터 파일의 해당 id값 :  [<Question 258>]
# 데이터 파일의 our_ref :  T198122
# 데이터 파일 내 일치 our_ref 존재 :  258
# ===============
# 엑셀 파일의 our_ref :  T198123
# 데이터 파일의 해당 id값 :  [<Question 259>]
# 데이터 파일의 our_ref :  T198123
# 데이터 파일 내 일치 our_ref 존재 :  259
# ===============
# 엑셀 파일의 our_ref :  T198124
# 데이터 파일의 해당 id값 :  [<Question 260>]
# 데이터 파일의 our_ref :  T198124
# 데이터 파일 내 일치 our_ref 존재 :  260
# ===============
# 엑셀 파일의 our_ref :  T198363
# 데이터 파일의 해당 id값 :  [<Question 261>]
# 데이터 파일의 our_ref :  T198363
# 데이터 파일 내 일치 our_ref 존재 :  261
# ===============
# 엑셀 파일의 our_ref :  T198364
# 데이터 파일의 해당 id값 :  [<Question 262>]
# 데이터 파일의 our_ref :  T198364
# 데이터 파일 내 일치 our_ref 존재 :  262
# ===============
# 엑셀 파일의 our_ref :  P198082
# 데이터 파일의 해당 id값 :  [<Question 263>]
# 데이터 파일의 our_ref :  P198082
# 데이터 파일 내 일치 our_ref 존재 :  263
# ===============
# 엑셀 파일의 our_ref :  P208047
# 데이터 파일의 해당 id값 :  [<Question 264>]
# 데이터 파일의 our_ref :  P208047
# 데이터 파일 내 일치 our_ref 존재 :  264
# ===============
# 엑셀 파일의 our_ref :  T198370
# 데이터 파일의 해당 id값 :  [<Question 265>]
# 데이터 파일의 our_ref :  T198370
# 데이터 파일 내 일치 our_ref 존재 :  265
# ===============
# 엑셀 파일의 our_ref :  T198372
# 데이터 파일의 해당 id값 :  [<Question 266>]
# 데이터 파일의 our_ref :  T198372
# 데이터 파일 내 일치 our_ref 존재 :  266
# ===============
# 엑셀 파일의 our_ref :  T198241
# 데이터 파일의 해당 id값 :  [<Question 267>]
# 데이터 파일의 our_ref :  T198241
# 데이터 파일 내 일치 our_ref 존재 :  267
# ===============
# 엑셀 파일의 our_ref :  T198365
# 데이터 파일의 해당 id값 :  [<Question 268>]
# 데이터 파일의 our_ref :  T198365
# 데이터 파일 내 일치 our_ref 존재 :  268
# ===============
# 엑셀 파일의 our_ref :  P198071
# 데이터 파일의 해당 id값 :  [<Question 269>]
# 데이터 파일의 our_ref :  P198071
# 데이터 파일 내 일치 our_ref 존재 :  269
# ===============
# 엑셀 파일의 our_ref :  D198055
# 데이터 파일의 해당 id값 :  [<Question 270>]
# 데이터 파일의 our_ref :  D198055
# 데이터 파일 내 일치 our_ref 존재 :  270
# ===============
# 엑셀 파일의 our_ref :  T198242
# 데이터 파일의 해당 id값 :  [<Question 271>]
# 데이터 파일의 our_ref :  T198242
# 데이터 파일 내 일치 our_ref 존재 :  271
# ===============
# 엑셀 파일의 our_ref :  T198244
# 데이터 파일의 해당 id값 :  [<Question 272>]
# 데이터 파일의 our_ref :  T198244
# 데이터 파일 내 일치 our_ref 존재 :  272
# ===============
# 엑셀 파일의 our_ref :  U198002
# 데이터 파일의 해당 id값 :  [<Question 273>]
# 데이터 파일의 our_ref :  U198002
# 데이터 파일 내 일치 our_ref 존재 :  273
# ===============
# 엑셀 파일의 our_ref :  T198366
# 데이터 파일의 해당 id값 :  [<Question 274>]
# 데이터 파일의 our_ref :  T198366
# 데이터 파일 내 일치 our_ref 존재 :  274
# ===============
# 엑셀 파일의 our_ref :  T198368
# 데이터 파일의 해당 id값 :  [<Question 275>]
# 데이터 파일의 our_ref :  T198368
# 데이터 파일 내 일치 our_ref 존재 :  275
# ===============
# 엑셀 파일의 our_ref :  T198369
# 데이터 파일의 해당 id값 :  [<Question 276>]
# 데이터 파일의 our_ref :  T198369
# 데이터 파일 내 일치 our_ref 존재 :  276
# ===============
# 엑셀 파일의 our_ref :  T198371
# 데이터 파일의 해당 id값 :  [<Question 277>]
# 데이터 파일의 our_ref :  T198371
# 데이터 파일 내 일치 our_ref 존재 :  277
# ===============
# 엑셀 파일의 our_ref :  D198022
# 데이터 파일의 해당 id값 :  [<Question 278>]
# 데이터 파일의 our_ref :  D198022
# 데이터 파일 내 일치 our_ref 존재 :  278
# ===============
# 엑셀 파일의 our_ref :  D198023
# 데이터 파일의 해당 id값 :  [<Question 279>]
# 데이터 파일의 our_ref :  D198023
# 데이터 파일 내 일치 our_ref 존재 :  279
# ===============
# 엑셀 파일의 our_ref :  T198114
# 데이터 파일의 해당 id값 :  [<Question 280>]
# 데이터 파일의 our_ref :  T198114
# 데이터 파일 내 일치 our_ref 존재 :  280
# ===============
# 엑셀 파일의 our_ref :  T198115
# 데이터 파일의 해당 id값 :  [<Question 281>]
# 데이터 파일의 our_ref :  T198115
# 데이터 파일 내 일치 our_ref 존재 :  281
# ===============
# 엑셀 파일의 our_ref :  T198116
# 데이터 파일의 해당 id값 :  [<Question 282>]
# 데이터 파일의 our_ref :  T198116
# 데이터 파일 내 일치 our_ref 존재 :  282
# ===============
# 엑셀 파일의 our_ref :  P198083
# 데이터 파일의 해당 id값 :  [<Question 283>]
# 데이터 파일의 our_ref :  P198083
# 데이터 파일 내 일치 our_ref 존재 :  283
# ===============
# 엑셀 파일의 our_ref :  P198084
# 데이터 파일의 해당 id값 :  [<Question 284>]
# 데이터 파일의 our_ref :  P198084
# 데이터 파일 내 일치 our_ref 존재 :  284
# ===============
# 엑셀 파일의 our_ref :  T198127
# 데이터 파일의 해당 id값 :  [<Question 285>]
# 데이터 파일의 our_ref :  T198127
# 데이터 파일 내 일치 our_ref 존재 :  285
# ===============
# 엑셀 파일의 our_ref :  P198085
# 데이터 파일의 해당 id값 :  [<Question 286>]
# 데이터 파일의 our_ref :  P198085
# 데이터 파일 내 일치 our_ref 존재 :  286
# ===============
# 엑셀 파일의 our_ref :  P198086
# 데이터 파일의 해당 id값 :  [<Question 287>]
# 데이터 파일의 our_ref :  P198086
# 데이터 파일 내 일치 our_ref 존재 :  287
# ===============
# 엑셀 파일의 our_ref :  D198033
# 데이터 파일의 해당 id값 :  [<Question 288>]
# 데이터 파일의 our_ref :  D198033
# 데이터 파일 내 일치 our_ref 존재 :  288
# ===============
# 엑셀 파일의 our_ref :  P198078
# 데이터 파일의 해당 id값 :  [<Question 289>]
# 데이터 파일의 our_ref :  P198078
# 데이터 파일 내 일치 our_ref 존재 :  289
# ===============
# 엑셀 파일의 our_ref :  P198079
# 데이터 파일의 해당 id값 :  [<Question 290>]
# 데이터 파일의 our_ref :  P198079
# 데이터 파일 내 일치 our_ref 존재 :  290
# ===============
# 엑셀 파일의 our_ref :  P198080
# 데이터 파일의 해당 id값 :  [<Question 291>]
# 데이터 파일의 our_ref :  P198080
# 데이터 파일 내 일치 our_ref 존재 :  291
# ===============
# 엑셀 파일의 our_ref :  T198126
# 데이터 파일의 해당 id값 :  [<Question 292>]
# 데이터 파일의 our_ref :  T198126
# 데이터 파일 내 일치 our_ref 존재 :  292
# ===============
# 엑셀 파일의 our_ref :  P198081
# 데이터 파일의 해당 id값 :  [<Question 293>]
# 데이터 파일의 our_ref :  P198081
# 데이터 파일 내 일치 our_ref 존재 :  293
# ===============
# 엑셀 파일의 our_ref :  T198137
# 데이터 파일의 해당 id값 :  [<Question 294>]
# 데이터 파일의 our_ref :  T198137
# 데이터 파일 내 일치 our_ref 존재 :  294
# ===============
# 엑셀 파일의 our_ref :  T198128
# 데이터 파일의 해당 id값 :  [<Question 295>]
# 데이터 파일의 our_ref :  T198128
# 데이터 파일 내 일치 our_ref 존재 :  295
# ===============
# 엑셀 파일의 our_ref :  T198129
# 데이터 파일의 해당 id값 :  [<Question 296>]
# 데이터 파일의 our_ref :  T198129
# 데이터 파일 내 일치 our_ref 존재 :  296
# ===============
# 엑셀 파일의 our_ref :  T198133
# 데이터 파일의 해당 id값 :  [<Question 297>]
# 데이터 파일의 our_ref :  T198133
# 데이터 파일 내 일치 our_ref 존재 :  297
# ===============
# 엑셀 파일의 our_ref :  T198134
# 데이터 파일의 해당 id값 :  [<Question 298>]
# 데이터 파일의 our_ref :  T198134
# 데이터 파일 내 일치 our_ref 존재 :  298
# ===============
# 엑셀 파일의 our_ref :  T198136
# 데이터 파일의 해당 id값 :  [<Question 299>]
# 데이터 파일의 our_ref :  T198136
# 데이터 파일 내 일치 our_ref 존재 :  299
# ===============
# 엑셀 파일의 our_ref :  T198117
# 데이터 파일의 해당 id값 :  [<Question 300>]
# 데이터 파일의 our_ref :  T198117
# 데이터 파일 내 일치 our_ref 존재 :  300
# ===============
# 엑셀 파일의 our_ref :  P198088
# 데이터 파일의 해당 id값 :  [<Question 301>]
# 데이터 파일의 our_ref :  P198088
# 데이터 파일 내 일치 our_ref 존재 :  301
# ===============
# 엑셀 파일의 our_ref :  P198090
# 데이터 파일의 해당 id값 :  [<Question 302>]
# 데이터 파일의 our_ref :  P198090
# 데이터 파일 내 일치 our_ref 존재 :  302
# ===============
# 엑셀 파일의 our_ref :  T198251
# 데이터 파일의 해당 id값 :  [<Question 303>]
# 데이터 파일의 our_ref :  T198251
# 데이터 파일 내 일치 our_ref 존재 :  303
# ===============
# 엑셀 파일의 our_ref :  P198092
# 데이터 파일의 해당 id값 :  [<Question 304>]
# 데이터 파일의 our_ref :  P198092
# 데이터 파일 내 일치 our_ref 존재 :  304
# ===============
# 엑셀 파일의 our_ref :  P198094
# 데이터 파일의 해당 id값 :  [<Question 305>]
# 데이터 파일의 our_ref :  P198094
# 데이터 파일 내 일치 our_ref 존재 :  305
# ===============
# 엑셀 파일의 our_ref :  P198095
# 데이터 파일의 해당 id값 :  [<Question 306>]
# 데이터 파일의 our_ref :  P198095
# 데이터 파일 내 일치 our_ref 존재 :  306
# ===============
# 엑셀 파일의 our_ref :  T198148
# 데이터 파일의 해당 id값 :  [<Question 307>]
# 데이터 파일의 our_ref :  T198148
# 데이터 파일 내 일치 our_ref 존재 :  307
# ===============
# 엑셀 파일의 our_ref :  P198101
# 데이터 파일의 해당 id값 :  [<Question 308>]
# 데이터 파일의 our_ref :  P198101
# 데이터 파일 내 일치 our_ref 존재 :  308
# ===============
# 엑셀 파일의 our_ref :  P198207
# 데이터 파일의 해당 id값 :  [<Question 309>]
# 데이터 파일의 our_ref :  P198207
# 데이터 파일 내 일치 our_ref 존재 :  309
# ===============
# 엑셀 파일의 our_ref :  P208652
# 데이터 파일의 해당 id값 :  [<Question 310>]
# 데이터 파일의 our_ref :  P208652
# 데이터 파일 내 일치 our_ref 존재 :  310
# ===============
# 엑셀 파일의 our_ref :  P208656
# 데이터 파일의 해당 id값 :  [<Question 311>]
# 데이터 파일의 our_ref :  P208656
# 데이터 파일 내 일치 our_ref 존재 :  311
# ===============
# 엑셀 파일의 our_ref :  P198097
# 데이터 파일의 해당 id값 :  [<Question 312>]
# 데이터 파일의 our_ref :  P198097
# 데이터 파일 내 일치 our_ref 존재 :  312
# ===============
# 엑셀 파일의 our_ref :  T208022
# 데이터 파일의 해당 id값 :  [<Question 313>]
# 데이터 파일의 our_ref :  T208022
# 데이터 파일 내 일치 our_ref 존재 :  313
# ===============
# 엑셀 파일의 our_ref :  P208056
# 데이터 파일의 해당 id값 :  [<Question 314>]
# 데이터 파일의 our_ref :  P208056
# 데이터 파일 내 일치 our_ref 존재 :  314
# ===============
# 엑셀 파일의 our_ref :  P198089
# 데이터 파일의 해당 id값 :  [<Question 315>]
# 데이터 파일의 our_ref :  P198089
# 데이터 파일 내 일치 our_ref 존재 :  315
# ===============
# 엑셀 파일의 our_ref :  P198093
# 데이터 파일의 해당 id값 :  [<Question 316>]
# 데이터 파일의 our_ref :  P198093
# 데이터 파일 내 일치 our_ref 존재 :  316
# ===============
# 엑셀 파일의 our_ref :  P198209
# 데이터 파일의 해당 id값 :  [<Question 317>]
# 데이터 파일의 our_ref :  P198209
# 데이터 파일 내 일치 our_ref 존재 :  317
# ===============
# 엑셀 파일의 our_ref :  P208654
# 데이터 파일의 해당 id값 :  [<Question 318>]
# 데이터 파일의 our_ref :  P208654
# 데이터 파일 내 일치 our_ref 존재 :  318
# ===============
# 엑셀 파일의 our_ref :  P198098
# 데이터 파일의 해당 id값 :  [<Question 319>]
# 데이터 파일의 our_ref :  P198098
# 데이터 파일 내 일치 our_ref 존재 :  319
# ===============
# 엑셀 파일의 our_ref :  P198099
# 데이터 파일의 해당 id값 :  [<Question 320>]
# 데이터 파일의 our_ref :  P198099
# 데이터 파일 내 일치 our_ref 존재 :  320
# ===============
# 엑셀 파일의 our_ref :  D198038
# 데이터 파일의 해당 id값 :  [<Question 321>]
# 데이터 파일의 our_ref :  D198038
# 데이터 파일 내 일치 our_ref 존재 :  321
# ===============
# 엑셀 파일의 our_ref :  P198103
# 데이터 파일의 해당 id값 :  [<Question 322>]
# 데이터 파일의 our_ref :  P198103
# 데이터 파일 내 일치 our_ref 존재 :  322
# ===============
# 엑셀 파일의 our_ref :  T198154
# 데이터 파일의 해당 id값 :  [<Question 323>]
# 데이터 파일의 our_ref :  T198154
# 데이터 파일 내 일치 our_ref 존재 :  323
# ===============
# 엑셀 파일의 our_ref :  T208021
# 데이터 파일의 해당 id값 :  [<Question 324>]
# 데이터 파일의 our_ref :  T208021
# 데이터 파일 내 일치 our_ref 존재 :  324
# ===============
# 엑셀 파일의 our_ref :  T188520
# 데이터 파일의 해당 id값 :  [<Question 325>]
# 데이터 파일의 our_ref :  T188520
# 데이터 파일 내 일치 our_ref 존재 :  325
# ===============
# 엑셀 파일의 our_ref :  T208114
# 데이터 파일의 해당 id값 :  [<Question 326>]
# 데이터 파일의 our_ref :  T208114
# 데이터 파일 내 일치 our_ref 존재 :  326
# ===============
# 엑셀 파일의 our_ref :  T208118
# 데이터 파일의 해당 id값 :  [<Question 327>]
# 데이터 파일의 our_ref :  T208118
# 데이터 파일 내 일치 our_ref 존재 :  327
# ===============
# 엑셀 파일의 our_ref :  T208119
# 데이터 파일의 해당 id값 :  [<Question 328>]
# 데이터 파일의 our_ref :  T208119
# 데이터 파일 내 일치 our_ref 존재 :  328
# ===============
# 엑셀 파일의 our_ref :  T198247
# 데이터 파일의 해당 id값 :  [<Question 329>]
# 데이터 파일의 our_ref :  T198247
# 데이터 파일 내 일치 our_ref 존재 :  329
# ===============
# 엑셀 파일의 our_ref :  T198254
# 데이터 파일의 해당 id값 :  [<Question 330>]
# 데이터 파일의 our_ref :  T198254
# 데이터 파일 내 일치 our_ref 존재 :  330
# ===============
# 엑셀 파일의 our_ref :  P198113
# 데이터 파일의 해당 id값 :  [<Question 331>]
# 데이터 파일의 our_ref :  P198113
# 데이터 파일 내 일치 our_ref 존재 :  331
# ===============
# 엑셀 파일의 our_ref :  T198167
# 데이터 파일의 해당 id값 :  [<Question 332>]
# 데이터 파일의 our_ref :  T198167
# 데이터 파일 내 일치 our_ref 존재 :  332
# ===============
# 엑셀 파일의 our_ref :  T198376
# 데이터 파일의 해당 id값 :  [<Question 333>]
# 데이터 파일의 our_ref :  T198376
# 데이터 파일 내 일치 our_ref 존재 :  333
# ===============
# 엑셀 파일의 our_ref :  D208005
# 데이터 파일의 해당 id값 :  [<Question 334>]
# 데이터 파일의 our_ref :  D208005
# 데이터 파일 내 일치 our_ref 존재 :  334
# ===============
# 엑셀 파일의 our_ref :  P208243
# 데이터 파일의 해당 id값 :  [<Question 335>]
# 데이터 파일의 our_ref :  P208243
# 데이터 파일 내 일치 our_ref 존재 :  335
# ===============
# 엑셀 파일의 our_ref :  T198375
# 데이터 파일의 해당 id값 :  [<Question 336>]
# 데이터 파일의 our_ref :  T198375
# 데이터 파일 내 일치 our_ref 존재 :  336
# ===============
# 엑셀 파일의 our_ref :  T198377
# 데이터 파일의 해당 id값 :  [<Question 337>]
# 데이터 파일의 our_ref :  T198377
# 데이터 파일 내 일치 our_ref 존재 :  337
# ===============
# 엑셀 파일의 our_ref :  T198378
# 데이터 파일의 해당 id값 :  [<Question 338>]
# 데이터 파일의 our_ref :  T198378
# 데이터 파일 내 일치 our_ref 존재 :  338
# ===============
# 엑셀 파일의 our_ref :  T198379
# 데이터 파일의 해당 id값 :  [<Question 339>]
# 데이터 파일의 our_ref :  T198379
# 데이터 파일 내 일치 our_ref 존재 :  339
# ===============
# 엑셀 파일의 our_ref :  T198380
# 데이터 파일의 해당 id값 :  [<Question 340>]
# 데이터 파일의 our_ref :  T198380
# 데이터 파일 내 일치 our_ref 존재 :  340
# ===============
# 엑셀 파일의 our_ref :  T198383
# 데이터 파일의 해당 id값 :  [<Question 341>]
# 데이터 파일의 our_ref :  T198383
# 데이터 파일 내 일치 our_ref 존재 :  341
# ===============
# 엑셀 파일의 our_ref :  P198325
# 데이터 파일의 해당 id값 :  [<Question 342>]
# 데이터 파일의 our_ref :  P198325
# 데이터 파일 내 일치 our_ref 존재 :  342
# ===============
# 엑셀 파일의 our_ref :  T198374
# 데이터 파일의 해당 id값 :  [<Question 343>]
# 데이터 파일의 our_ref :  T198374
# 데이터 파일 내 일치 our_ref 존재 :  343
# ===============
# 엑셀 파일의 our_ref :  T198386
# 데이터 파일의 해당 id값 :  [<Question 344>]
# 데이터 파일의 our_ref :  T198386
# 데이터 파일 내 일치 our_ref 존재 :  344
# ===============
# 엑셀 파일의 our_ref :  T198160
# 데이터 파일의 해당 id값 :  [<Question 345>]
# 데이터 파일의 our_ref :  T198160
# 데이터 파일 내 일치 our_ref 존재 :  345
# ===============
# 엑셀 파일의 our_ref :  T198162
# 데이터 파일의 해당 id값 :  [<Question 346>]
# 데이터 파일의 our_ref :  T198162
# 데이터 파일 내 일치 our_ref 존재 :  346
# ===============
# 엑셀 파일의 our_ref :  P208058
# 데이터 파일의 해당 id값 :  [<Question 347>]
# 데이터 파일의 our_ref :  P208058
# 데이터 파일 내 일치 our_ref 존재 :  347
# ===============
# 엑셀 파일의 our_ref :  P198121
# 데이터 파일의 해당 id값 :  [<Question 348>]
# 데이터 파일의 our_ref :  P198121
# 데이터 파일 내 일치 our_ref 존재 :  348
# ===============
# 엑셀 파일의 our_ref :  T198373
# 데이터 파일의 해당 id값 :  [<Question 349>]
# 데이터 파일의 our_ref :  T198373
# 데이터 파일 내 일치 our_ref 존재 :  349
# ===============
# 엑셀 파일의 our_ref :  T208117
# 데이터 파일의 해당 id값 :  [<Question 350>]
# 데이터 파일의 our_ref :  T208117
# 데이터 파일 내 일치 our_ref 존재 :  350
# ===============
# 엑셀 파일의 our_ref :  P208237
# 데이터 파일의 해당 id값 :  [<Question 351>]
# 데이터 파일의 our_ref :  P208237
# 데이터 파일 내 일치 our_ref 존재 :  351
# ===============
# 엑셀 파일의 our_ref :  P208101
# 데이터 파일의 해당 id값 :  [<Question 352>]
# 데이터 파일의 our_ref :  P208101
# 데이터 파일 내 일치 our_ref 존재 :  352
# ===============
# 엑셀 파일의 our_ref :  P188452
# 데이터 파일의 해당 id값 :  [<Question 353>]
# 데이터 파일의 our_ref :  P188452
# 데이터 파일 내 일치 our_ref 존재 :  353
# ===============
# 엑셀 파일의 our_ref :  P208061
# 데이터 파일의 해당 id값 :  [<Question 354>]
# 데이터 파일의 our_ref :  P208061
# 데이터 파일 내 일치 our_ref 존재 :  354
# ===============
# 엑셀 파일의 our_ref :  T188644
# 데이터 파일의 해당 id값 :  [<Question 355>]
# 데이터 파일의 our_ref :  T188644
# 데이터 파일 내 일치 our_ref 존재 :  355
# ===============
# 엑셀 파일의 our_ref :  T198155
# 데이터 파일의 해당 id값 :  [<Question 356>]
# 데이터 파일의 our_ref :  T198155
# 데이터 파일 내 일치 our_ref 존재 :  356
# ===============
# 엑셀 파일의 our_ref :  T198156
# 데이터 파일의 해당 id값 :  [<Question 357>]
# 데이터 파일의 our_ref :  T198156
# 데이터 파일 내 일치 our_ref 존재 :  357
# ===============
# 엑셀 파일의 our_ref :  T188679
# 데이터 파일의 해당 id값 :  [<Question 358>]
# 데이터 파일의 our_ref :  T188679
# 데이터 파일 내 일치 our_ref 존재 :  358
# ===============
# 엑셀 파일의 our_ref :  T188680
# 데이터 파일의 해당 id값 :  [<Question 359>]
# 데이터 파일의 our_ref :  T188680
# 데이터 파일 내 일치 our_ref 존재 :  359
# ===============
# 엑셀 파일의 our_ref :  P188476
# ...
# 데이터 파일 내 일치 our_ref 존재 :  6806
# ===============
# 엑셀 파일의 our_ref :  P221699
# 데이터 파일의 해당 id값 :  [<Question 6806>]
# 데이터 파일의 our_ref :  P221699
# 데이터 파일 내 일치 our_ref 존재 :  6807
# ===============
# 엑셀 파일의 our_ref :  P221824
# 데이터 파일의 해당 id값 :  [<Question 6807>]
# 데이터 파일의 our_ref :  P221824
# 데이터 파일 내 일치 our_ref 존재 :  6808
# ===============
# 엑셀 파일의 our_ref :  P221825
# 데이터 파일의 해당 id값 :  [<Question 6808>]
# 데이터 파일의 our_ref :  P221825
# 데이터 파일 내 일치 our_ref 존재 :  6809
# ===============
# 엑셀 파일의 our_ref :  P221700
# 데이터 파일의 해당 id값 :  [<Question 6809>]
# 데이터 파일의 our_ref :  P221700
# 데이터 파일 내 일치 our_ref 존재 :  6810
# ===============
# 엑셀 파일의 our_ref :  P208169-RE
# 데이터 파일의 해당 id값 :  [<Question 6810>]
# 데이터 파일의 our_ref :  P208169-RE
# 데이터 파일 내 일치 our_ref 존재 :  6811
# ===============
# 엑셀 파일의 our_ref :  P208401-RE
# 데이터 파일의 해당 id값 :  [<Question 6811>]
# 데이터 파일의 our_ref :  P208401-RE
# 데이터 파일 내 일치 our_ref 존재 :  6812
# ===============
# 엑셀 파일의 our_ref :  P221161-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6812>]
# 데이터 파일의 our_ref :  P221161-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6813
# ===============
# 엑셀 파일의 our_ref :  P221659
# 데이터 파일의 해당 id값 :  [<Question 6813>]
# 데이터 파일의 our_ref :  P221659
# 데이터 파일 내 일치 our_ref 존재 :  6814
# ===============
# 엑셀 파일의 our_ref :  P221161-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6814>]
# 데이터 파일의 our_ref :  P221161-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6815
# ===============
# 엑셀 파일의 our_ref :  P221613
# 데이터 파일의 해당 id값 :  [<Question 6815>]
# 데이터 파일의 our_ref :  P221613
# 데이터 파일 내 일치 our_ref 존재 :  6816
# ===============
# 엑셀 파일의 our_ref :  P221769
# 데이터 파일의 해당 id값 :  [<Question 6816>]
# 데이터 파일의 our_ref :  P221769
# 데이터 파일 내 일치 our_ref 존재 :  6817
# ===============
# 엑셀 파일의 our_ref :  P221109
# 데이터 파일의 해당 id값 :  [<Question 6817>]
# 데이터 파일의 our_ref :  P221109
# 데이터 파일 내 일치 our_ref 존재 :  6818
# ===============
# 엑셀 파일의 our_ref :  P221459
# 데이터 파일의 해당 id값 :  [<Question 6818>]
# 데이터 파일의 our_ref :  P221459
# 데이터 파일 내 일치 our_ref 존재 :  6819
# ===============
# 엑셀 파일의 our_ref :  P221839
# 데이터 파일의 해당 id값 :  [<Question 6819>]
# 데이터 파일의 our_ref :  P221839
# 데이터 파일 내 일치 our_ref 존재 :  6820
# ===============
# 엑셀 파일의 our_ref :  P221831
# 데이터 파일의 해당 id값 :  [<Question 6820>]
# 데이터 파일의 our_ref :  P221831
# 데이터 파일 내 일치 our_ref 존재 :  6821
# ===============
# 엑셀 파일의 our_ref :  P221474
# 데이터 파일의 해당 id값 :  [<Question 6821>]
# 데이터 파일의 our_ref :  P221474
# 데이터 파일 내 일치 our_ref 존재 :  6822
# ===============
# 엑셀 파일의 our_ref :  P221833
# 데이터 파일의 해당 id값 :  [<Question 6822>]
# 데이터 파일의 our_ref :  P221833
# 데이터 파일 내 일치 our_ref 존재 :  6823
# ===============
# 엑셀 파일의 our_ref :  P221619
# 데이터 파일의 해당 id값 :  [<Question 6823>]
# 데이터 파일의 our_ref :  P221619
# 데이터 파일 내 일치 our_ref 존재 :  6824
# ===============
# 엑셀 파일의 our_ref :  P221474-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6824>]
# 데이터 파일의 our_ref :  P221474-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6825
# ===============
# 엑셀 파일의 our_ref :  P221474-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6825>]
# 데이터 파일의 our_ref :  P221474-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6826
# ===============
# 엑셀 파일의 our_ref :  P221451
# 데이터 파일의 해당 id값 :  [<Question 6826>]
# 데이터 파일의 our_ref :  P221451
# 데이터 파일 내 일치 our_ref 존재 :  6827
# ===============
# 엑셀 파일의 our_ref :  P221449-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6827>]
# 데이터 파일의 our_ref :  P221449-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6828
# ===============
# 엑셀 파일의 our_ref :  P221450
# 데이터 파일의 해당 id값 :  [<Question 6828>]
# 데이터 파일의 our_ref :  P221450
# 데이터 파일 내 일치 our_ref 존재 :  6829
# ===============
# 엑셀 파일의 our_ref :  P221711-RE
# 데이터 파일의 해당 id값 :  [<Question 6829>]
# 데이터 파일의 our_ref :  P221711-RE
# 데이터 파일 내 일치 our_ref 존재 :  6830
# ===============
# 엑셀 파일의 our_ref :  P221449
# 데이터 파일의 해당 id값 :  [<Question 6830>]
# 데이터 파일의 our_ref :  P221449
# 데이터 파일 내 일치 our_ref 존재 :  6831
# ===============
# 엑셀 파일의 our_ref :  P221570
# 데이터 파일의 해당 id값 :  [<Question 6831>]
# 데이터 파일의 our_ref :  P221570
# 데이터 파일 내 일치 our_ref 존재 :  6832
# ===============
# 엑셀 파일의 our_ref :  P221570-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6832>]
# 데이터 파일의 our_ref :  P221570-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6833
# ===============
# 엑셀 파일의 our_ref :  P221449-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6833>]
# 데이터 파일의 our_ref :  P221449-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6834
# ===============
# 엑셀 파일의 our_ref :  P221656
# 데이터 파일의 해당 id값 :  [<Question 6834>]
# 데이터 파일의 our_ref :  P221656
# 데이터 파일 내 일치 our_ref 존재 :  6835
# ===============
# 엑셀 파일의 our_ref :  P221552
# 데이터 파일의 해당 id값 :  [<Question 6835>]
# 데이터 파일의 our_ref :  P221552
# 데이터 파일 내 일치 our_ref 존재 :  6836
# ===============
# 엑셀 파일의 our_ref :  P221849
# 데이터 파일의 해당 id값 :  [<Question 6836>]
# 데이터 파일의 our_ref :  P221849
# 데이터 파일 내 일치 our_ref 존재 :  6837
# ===============
# 엑셀 파일의 our_ref :  P221570-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6837>]
# 데이터 파일의 our_ref :  P221570-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6838
# ===============
# 엑셀 파일의 our_ref :  P221884
# 데이터 파일의 해당 id값 :  [<Question 6838>]
# 데이터 파일의 our_ref :  P221884
# 데이터 파일 내 일치 our_ref 존재 :  6839
# ===============
# 엑셀 파일의 our_ref :  P221885
# 데이터 파일의 해당 id값 :  [<Question 6839>]
# 데이터 파일의 our_ref :  P221885
# 데이터 파일 내 일치 our_ref 존재 :  6840
# ===============
# 엑셀 파일의 our_ref :  P221650
# 데이터 파일의 해당 id값 :  [<Question 6840>]
# 데이터 파일의 our_ref :  P221650
# 데이터 파일 내 일치 our_ref 존재 :  6841
# ===============
# 엑셀 파일의 our_ref :  P221480
# 데이터 파일의 해당 id값 :  [<Question 6841>]
# 데이터 파일의 our_ref :  P221480
# 데이터 파일 내 일치 our_ref 존재 :  6842
# ===============
# 엑셀 파일의 our_ref :  P221727
# 데이터 파일의 해당 id값 :  [<Question 6842>]
# 데이터 파일의 our_ref :  P221727
# 데이터 파일 내 일치 our_ref 존재 :  6843
# ===============
# 엑셀 파일의 our_ref :  P221650-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6843>]
# 데이터 파일의 our_ref :  P221650-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6844
# ===============
# 엑셀 파일의 our_ref :  P221913
# 데이터 파일의 해당 id값 :  [<Question 6844>]
# 데이터 파일의 our_ref :  P221913
# 데이터 파일 내 일치 our_ref 존재 :  6845
# ===============
# 엑셀 파일의 our_ref :  P221914
# 데이터 파일의 해당 id값 :  [<Question 6845>]
# 데이터 파일의 our_ref :  P221914
# 데이터 파일 내 일치 our_ref 존재 :  6846
# ===============
# 엑셀 파일의 our_ref :  P221548
# 데이터 파일의 해당 id값 :  [<Question 6846>]
# 데이터 파일의 our_ref :  P221548
# 데이터 파일 내 일치 our_ref 존재 :  6847
# ===============
# 엑셀 파일의 our_ref :  P221434
# 데이터 파일의 해당 id값 :  [<Question 6847>]
# 데이터 파일의 our_ref :  P221434
# 데이터 파일 내 일치 our_ref 존재 :  6848
# ===============
# 엑셀 파일의 our_ref :  P221600
# 데이터 파일의 해당 id값 :  [<Question 6848>]
# 데이터 파일의 our_ref :  P221600
# 데이터 파일 내 일치 our_ref 존재 :  6849
# ===============
# 엑셀 파일의 our_ref :  P221523
# 데이터 파일의 해당 id값 :  [<Question 6849>]
# 데이터 파일의 our_ref :  P221523
# 데이터 파일 내 일치 our_ref 존재 :  6850
# ===============
# 엑셀 파일의 our_ref :  P221650-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6850>]
# 데이터 파일의 our_ref :  P221650-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6851
# ===============
# 엑셀 파일의 our_ref :  P221891
# 데이터 파일의 해당 id값 :  [<Question 6851>]
# 데이터 파일의 our_ref :  P221891
# 데이터 파일 내 일치 our_ref 존재 :  6852
# ===============
# 엑셀 파일의 our_ref :  P221598
# 데이터 파일의 해당 id값 :  [<Question 6852>]
# 데이터 파일의 our_ref :  P221598
# 데이터 파일 내 일치 our_ref 존재 :  6853
# ===============
# 엑셀 파일의 our_ref :  P221892
# 데이터 파일의 해당 id값 :  [<Question 6853>]
# 데이터 파일의 our_ref :  P221892
# 데이터 파일 내 일치 our_ref 존재 :  6854
# ===============
# 엑셀 파일의 our_ref :  P221580
# 데이터 파일의 해당 id값 :  [<Question 6854>]
# 데이터 파일의 our_ref :  P221580
# 데이터 파일 내 일치 our_ref 존재 :  6855
# ===============
# 엑셀 파일의 our_ref :  P221850
# 데이터 파일의 해당 id값 :  [<Question 6855>]
# 데이터 파일의 our_ref :  P221850
# 데이터 파일 내 일치 our_ref 존재 :  6856
# ===============
# 엑셀 파일의 our_ref :  P212842-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6856>]
# 데이터 파일의 our_ref :  P212842-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6857
# ===============
# 엑셀 파일의 our_ref :  P221676
# 데이터 파일의 해당 id값 :  [<Question 6857>]
# 데이터 파일의 our_ref :  P221676
# 데이터 파일 내 일치 our_ref 존재 :  6858
# ===============
# 엑셀 파일의 our_ref :  P221694
# 데이터 파일의 해당 id값 :  [<Question 6858>]
# 데이터 파일의 our_ref :  P221694
# 데이터 파일 내 일치 our_ref 존재 :  6859
# ===============
# 엑셀 파일의 our_ref :  P221588
# 데이터 파일의 해당 id값 :  [<Question 6859>]
# 데이터 파일의 our_ref :  P221588
# 데이터 파일 내 일치 our_ref 존재 :  6860
# ===============
# 엑셀 파일의 our_ref :  P221672
# 데이터 파일의 해당 id값 :  [<Question 6860>]
# 데이터 파일의 our_ref :  P221672
# 데이터 파일 내 일치 our_ref 존재 :  6861
# ===============
# 엑셀 파일의 our_ref :  P221672-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6861>]
# 데이터 파일의 our_ref :  P221672-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6862
# ===============
# 엑셀 파일의 our_ref :  P212842
# 데이터 파일의 해당 id값 :  [<Question 6862>]
# 데이터 파일의 our_ref :  P212842
# 데이터 파일 내 일치 our_ref 존재 :  6863
# ===============
# 엑셀 파일의 our_ref :  P221588-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6863>]
# 데이터 파일의 our_ref :  P221588-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6864
# ===============
# 엑셀 파일의 our_ref :  P221694-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6864>]
# 데이터 파일의 our_ref :  P221694-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6865
# ===============
# 엑셀 파일의 our_ref :  P212842-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6865>]
# 데이터 파일의 our_ref :  P212842-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6866
# ===============
# 엑셀 파일의 our_ref :  P221588-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6866>]
# 데이터 파일의 our_ref :  P221588-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6867
# ===============
# 엑셀 파일의 our_ref :  P221672-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6867>]
# 데이터 파일의 our_ref :  P221672-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6868
# ===============
# 엑셀 파일의 our_ref :  P221694-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6868>]
# 데이터 파일의 our_ref :  P221694-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6869
# ===============
# 엑셀 파일의 our_ref :  P221673
# 데이터 파일의 해당 id값 :  [<Question 6869>]
# 데이터 파일의 our_ref :  P221673
# 데이터 파일 내 일치 our_ref 존재 :  6870
# ===============
# 엑셀 파일의 our_ref :  P221391-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6870>]
# 데이터 파일의 our_ref :  P221391-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6871
# ===============
# 엑셀 파일의 our_ref :  P221391
# 데이터 파일의 해당 id값 :  [<Question 6871>]
# 데이터 파일의 our_ref :  P221391
# 데이터 파일 내 일치 our_ref 존재 :  6872
# ===============
# 엑셀 파일의 our_ref :  P221923
# 데이터 파일의 해당 id값 :  [<Question 6872>]
# 데이터 파일의 our_ref :  P221923
# 데이터 파일 내 일치 our_ref 존재 :  6873
# ===============
# 엑셀 파일의 our_ref :  P221924
# 데이터 파일의 해당 id값 :  [<Question 6873>]
# 데이터 파일의 our_ref :  P221924
# 데이터 파일 내 일치 our_ref 존재 :  6874
# ===============
# 엑셀 파일의 our_ref :  P221926
# 데이터 파일의 해당 id값 :  [<Question 6874>]
# 데이터 파일의 our_ref :  P221926
# 데이터 파일 내 일치 our_ref 존재 :  6875
# ===============
# 엑셀 파일의 our_ref :  P221927
# 데이터 파일의 해당 id값 :  [<Question 6875>]
# 데이터 파일의 our_ref :  P221927
# 데이터 파일 내 일치 our_ref 존재 :  6876
# ===============
# 엑셀 파일의 our_ref :  P221685
# 데이터 파일의 해당 id값 :  [<Question 6876>]
# 데이터 파일의 our_ref :  P221685
# 데이터 파일 내 일치 our_ref 존재 :  6877
# ===============
# 엑셀 파일의 our_ref :  P221391-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6877>]
# 데이터 파일의 our_ref :  P221391-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6878
# ===============
# 엑셀 파일의 our_ref :  P221933
# 데이터 파일의 해당 id값 :  [<Question 6878>]
# 데이터 파일의 our_ref :  P221933
# 데이터 파일 내 일치 our_ref 존재 :  6879
# ===============
# 엑셀 파일의 our_ref :  P221935
# 데이터 파일의 해당 id값 :  [<Question 6879>]
# 데이터 파일의 our_ref :  P221935
# 데이터 파일 내 일치 our_ref 존재 :  6880
# ===============
# 엑셀 파일의 our_ref :  P221920
# 데이터 파일의 해당 id값 :  [<Question 6880>]
# 데이터 파일의 our_ref :  P221920
# 데이터 파일 내 일치 our_ref 존재 :  6881
# ===============
# 엑셀 파일의 our_ref :  P221921
# 데이터 파일의 해당 id값 :  [<Question 6881>]
# 데이터 파일의 our_ref :  P221921
# 데이터 파일 내 일치 our_ref 존재 :  6882
# ===============
# 엑셀 파일의 our_ref :  P221558
# 데이터 파일의 해당 id값 :  [<Question 6882>]
# 데이터 파일의 our_ref :  P221558
# 데이터 파일 내 일치 our_ref 존재 :  6883
# ===============
# 엑셀 파일의 our_ref :  P221934
# 데이터 파일의 해당 id값 :  [<Question 6883>]
# 데이터 파일의 our_ref :  P221934
# 데이터 파일 내 일치 our_ref 존재 :  6884
# ===============
# 엑셀 파일의 our_ref :  P221936
# 데이터 파일의 해당 id값 :  [<Question 6884>]
# 데이터 파일의 our_ref :  P221936
# 데이터 파일 내 일치 our_ref 존재 :  6885
# ===============
# 엑셀 파일의 our_ref :  P221524
# 데이터 파일의 해당 id값 :  [<Question 6885>]
# 데이터 파일의 our_ref :  P221524
# 데이터 파일 내 일치 our_ref 존재 :  6886
# ===============
# 엑셀 파일의 our_ref :  P221524-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6886>]
# 데이터 파일의 our_ref :  P221524-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6887
# ===============
# 엑셀 파일의 our_ref :  P221332
# 데이터 파일의 해당 id값 :  [<Question 6887>]
# 데이터 파일의 our_ref :  P221332
# 데이터 파일 내 일치 our_ref 존재 :  6888
# ===============
# 엑셀 파일의 our_ref :  P221707
# 데이터 파일의 해당 id값 :  [<Question 6888>]
# 데이터 파일의 our_ref :  P221707
# 데이터 파일 내 일치 our_ref 존재 :  6889
# ===============
# 엑셀 파일의 our_ref :  P221937
# 데이터 파일의 해당 id값 :  [<Question 6889>]
# 데이터 파일의 our_ref :  P221937
# 데이터 파일 내 일치 our_ref 존재 :  6890
# ===============
# 엑셀 파일의 our_ref :  P221504
# 데이터 파일의 해당 id값 :  [<Question 6890>]
# 데이터 파일의 our_ref :  P221504
# 데이터 파일 내 일치 our_ref 존재 :  6891
# ===============
# 엑셀 파일의 our_ref :  P221663
# 데이터 파일의 해당 id값 :  [<Question 6891>]
# 데이터 파일의 our_ref :  P221663
# 데이터 파일 내 일치 our_ref 존재 :  6892
# ===============
# 엑셀 파일의 our_ref :  P221666
# 데이터 파일의 해당 id값 :  [<Question 6892>]
# 데이터 파일의 our_ref :  P221666
# 데이터 파일 내 일치 our_ref 존재 :  6893
# ===============
# 엑셀 파일의 our_ref :  P221955
# 데이터 파일의 해당 id값 :  [<Question 6893>]
# 데이터 파일의 our_ref :  P221955
# 데이터 파일 내 일치 our_ref 존재 :  6894
# ===============
# 엑셀 파일의 our_ref :  P221667
# 데이터 파일의 해당 id값 :  [<Question 6894>]
# 데이터 파일의 our_ref :  P221667
# 데이터 파일 내 일치 our_ref 존재 :  6895
# ===============
# 엑셀 파일의 our_ref :  P221668
# 데이터 파일의 해당 id값 :  [<Question 6895>]
# 데이터 파일의 our_ref :  P221668
# 데이터 파일 내 일치 our_ref 존재 :  6896
# ===============
# 엑셀 파일의 our_ref :  P221953
# 데이터 파일의 해당 id값 :  [<Question 6896>]
# 데이터 파일의 our_ref :  P221953
# 데이터 파일 내 일치 our_ref 존재 :  6897
# ===============
# 엑셀 파일의 our_ref :  P221524-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6897>]
# 데이터 파일의 our_ref :  P221524-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6898
# ===============
# 엑셀 파일의 our_ref :  P221503
# 데이터 파일의 해당 id값 :  [<Question 6898>]
# 데이터 파일의 our_ref :  P221503
# 데이터 파일 내 일치 our_ref 존재 :  6899
# ===============
# 엑셀 파일의 our_ref :  P221564
# 데이터 파일의 해당 id값 :  [<Question 6899>]
# 데이터 파일의 our_ref :  P221564
# 데이터 파일 내 일치 our_ref 존재 :  6900
# ===============
# 엑셀 파일의 our_ref :  P221564-PRO1
# 데이터 파일의 해당 id값 :  [<Question 6900>]
# 데이터 파일의 our_ref :  P221564-PRO1
# 데이터 파일 내 일치 our_ref 존재 :  6901
# ===============
# 엑셀 파일의 our_ref :  P221664
# 데이터 파일의 해당 id값 :  [<Question 6901>]
# 데이터 파일의 our_ref :  P221664
# 데이터 파일 내 일치 our_ref 존재 :  6902
# ===============
# 엑셀 파일의 our_ref :  P221665
# 데이터 파일의 해당 id값 :  [<Question 6902>]
# 데이터 파일의 our_ref :  P221665
# 데이터 파일 내 일치 our_ref 존재 :  6903
# ===============
# 엑셀 파일의 our_ref :  P221961
# 데이터 파일의 해당 id값 :  [<Question 6903>]
# 데이터 파일의 our_ref :  P221961
# 데이터 파일 내 일치 our_ref 존재 :  6904
# ===============
# 엑셀 파일의 our_ref :  P221962
# 데이터 파일의 해당 id값 :  [<Question 6904>]
# 데이터 파일의 our_ref :  P221962
# 데이터 파일 내 일치 our_ref 존재 :  6905
# ===============
# 엑셀 파일의 our_ref :  P221963
# 데이터 파일의 해당 id값 :  [<Question 6905>]
# 데이터 파일의 our_ref :  P221963
# 데이터 파일 내 일치 our_ref 존재 :  6906
# ===============
# 엑셀 파일의 our_ref :  PT221005
# 데이터 파일의 해당 id값 :  [<Question 6906>]
# 데이터 파일의 our_ref :  PT221005
# 데이터 파일 내 일치 our_ref 존재 :  6907
# ===============
# 엑셀 파일의 our_ref :  PT221007
# 데이터 파일의 해당 id값 :  [<Question 6907>]
# 데이터 파일의 our_ref :  PT221007
# 데이터 파일 내 일치 our_ref 존재 :  6908
# ===============
# 엑셀 파일의 our_ref :  PT221008
# 데이터 파일의 해당 id값 :  [<Question 6908>]
# 데이터 파일의 our_ref :  PT221008
# 데이터 파일 내 일치 our_ref 존재 :  6909
# ===============
# 엑셀 파일의 our_ref :  PT221009
# 데이터 파일의 해당 id값 :  [<Question 6909>]
# 데이터 파일의 our_ref :  PT221009
# 데이터 파일 내 일치 our_ref 존재 :  6910
# ===============
# 엑셀 파일의 our_ref :  P221550
# 데이터 파일의 해당 id값 :  [<Question 6910>]
# 데이터 파일의 our_ref :  P221550
# 데이터 파일 내 일치 our_ref 존재 :  6911
# ===============
# 엑셀 파일의 our_ref :  P221726-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6911>]
# 데이터 파일의 our_ref :  P221726-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6912
# ===============
# 엑셀 파일의 our_ref :  PT221006
# 데이터 파일의 해당 id값 :  [<Question 6912>]
# 데이터 파일의 our_ref :  PT221006
# 데이터 파일 내 일치 our_ref 존재 :  6913
# ===============
# 엑셀 파일의 our_ref :  P221564-PRO2
# 데이터 파일의 해당 id값 :  [<Question 6913>]
# 데이터 파일의 our_ref :  P221564-PRO2
# 데이터 파일 내 일치 our_ref 존재 :  6914
# ===============
# 엑셀 파일의 our_ref :  PT221004
# 데이터 파일의 해당 id값 :  [<Question 6914>]
# 데이터 파일의 our_ref :  PT221004
# 데이터 파일 내 일치 our_ref 존재 :  6915
# ===============
# 엑셀 파일의 our_ref :  P221683
# 데이터 파일의 해당 id값 :  [<Question 6915>]
# 데이터 파일의 our_ref :  P221683
# 데이터 파일 내 일치 our_ref 존재 :  6916
# ===============
# 엑셀 파일의 our_ref :  P221522
# 데이터 파일의 해당 id값 :  [<Question 6916>]
# 데이터 파일의 our_ref :  P221522
# 데이터 파일 내 일치 our_ref 존재 :  6917
# ===============
# 엑셀 파일의 our_ref :  PT221037
# 데이터 파일의 해당 id값 :  [<Question 6917>]
# 데이터 파일의 our_ref :  PT221037
# 데이터 파일 내 일치 our_ref 존재 :  6918
# ===============
# 엑셀 파일의 our_ref :  PT221038
# 데이터 파일의 해당 id값 :  [<Question 6918>]
# 데이터 파일의 our_ref :  PT221038
# 데이터 파일 내 일치 our_ref 존재 :  6919
# ===============
# 엑셀 파일의 our_ref :  PT221039
# 데이터 파일의 해당 id값 :  [<Question 6919>]
# 데이터 파일의 our_ref :  PT221039
# 데이터 파일 내 일치 our_ref 존재 :  6920
# ===============
# 엑셀 파일의 our_ref :  P211589-DIV2
# 데이터 파일의 해당 id값 :  [<Question 6920>]
# 데이터 파일의 our_ref :  P211589-DIV2
# 데이터 파일 내 일치 our_ref 존재 :  6921
# ===============

# %% [markdown]
# ▲▲ 데이터 업로드 기능 수정하기_03_종료_220721

# %% [markdown]
# ▼▼ 데이터 업로드 기능 수정하기_04_시작_220721

# %%
q = Question.query.get(2)

# %%
q
# Out:
# <Question 2>

# %%
q.our_ref='값 입력 테스트'

# %%
db.session.commit()

# %% [markdown]
# #-------------

# %% [markdown]
# #-------------

# %% [markdown]
# ▼▼▼ 이하 예제 시작(pybo 예제)

# %%
from pybo.models import User
from pybo import db

# %%
from pybo.forms import UserCreateForm, UserLoginForm
from flask import Blueprint, url_for, render_template, flash, request, session, g
from werkzeug.security import generate_password_hash, check_password_hash
from werkzeug.utils import redirect

# %%
from flask import Flask
from flask_migrate import Migrate
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import MetaData
import config
import config

# %%
from pybo import db
import pybo

# %%
from openpyxl import load_workbook
from pybo.models import User
from datetime import datetime
from pybo import db, create_app
import pybo

# %% [markdown]
# ▼▼▼ 예제중에 이게 있어야 했다.

# %%
from pybo import create_app
pybo = create_app()
pybo.app_context().push()

# %% [markdown]
# ▲▲▲ 예제중에 이게 있어야 했다.

# %%
print(User.query.count())
# Out:
# 14

# %%
app = Flask(__name__)
app.config.from_object(config)
    #app.config 환경 변수로 부르기 위해 app.config.from_object(config)코드를 추가함

# %%
with app.app_context():
    print(User.query.count())
    try:
        user = User(username='shin12350', password='shin_123450', email='shin50@naver.com')
        print(user)
        db.session.add(user)
        db.session.commit()
        print(User.query.count())
    except:
        db.session.rollback()
        raise
    finally:
        db.session.close()
    #db.create_all()
# Out:
# 5
# <User (transient 2597423975248)>
# 6

# %%
with app.app_context():
    print(User.query.count())
    try:
        user = User(username='shin12352', password='shin_123452', email='shin52@naver.com')
        print(user)
        db.session.add(user)
        db.session.commit()
        print(User.query.count())
        print('사용자 정보를 생성 하였습니다.')
    except:
        db.session.rollback()
        #raise
        print('사용중인 사용자 정보가 있습니다.')
        pass
    finally:
        db.session.close()
    #db.create_all()
print('종료')
# Out:
# 7
# <User (transient 2597424733200)>
# 8
# 사용자 정보를 생성 하였습니다.
# 종료

# %% [markdown]
# 이제 연속해서 하는걸 해보자

# %% [markdown]
# 원래 볼려고했던 최초 예제 참고

# %%
from openpyxl import load_workbook

# %%
wb = load_workbook(filename='db_test.xlsx')
ws = wb.active

# %%
ws
# Out:
# <Worksheet "Sheet1">

# %%
print(User.query.count())
# Out:
# 20

# %%
a = 0
with app.app_context():
    print('최초 시작시 User모델 데이터 개수 : ',User.query.count())
    for row in range(1, ws.max_row+1):
        try:
            #user = User(username='shin12352', password='shin_123452', email='shin52@naver.com')
            user = User(username=ws.cell(row,1).value, password=ws.cell(row,2).value, email=ws.cell(row,3).value)
            print(user)
            db.session.add(user)
            db.session.commit()
            print('사용자 정보를 생성 하였습니다.')
        except:
            db.session.rollback()
            print('입력에 에러가 발생 하였습니다.')
            pass
        finally:
            db.session.close()
        print(a," 번째 작업을 종료 합니다.")
        a = a+1
        print('='*10)

print("최종 작업 이후 User모델 데이터 개수 : ", User.query.count())
# Out:
# 최초 시작시 User모델 데이터 개수 :  20
# <User (transient 2788504735120)>
# 입력에 에러가 발생 하였습니다.
# 0  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788492368432)>
# 입력에 에러가 발생 하였습니다.
# 1  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504493984)>
# 입력에 에러가 발생 하였습니다.
# 2  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504735504)>
# 입력에 에러가 발생 하였습니다.
# 3  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504599952)>
# 입력에 에러가 발생 하였습니다.
# 4  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504694016)>
# 입력에 에러가 발생 하였습니다.
# 5  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504597072)>
# 입력에 에러가 발생 하였습니다.
# 6  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788492356000)>
# 입력에 에러가 발생 하였습니다.
# 7  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504598368)>
# 입력에 에러가 발생 하였습니다.
# 8  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504598080)>
# 입력에 에러가 발생 하였습니다.
# 9  번째 작업을 종료 합니다.
# ==========
# <User (transient 2788504490192)>
# 입력에 에러가 발생 하였습니다.
# 10  번째 작업을 종료 합니다.
# ==========
# 최종 작업 이후 User모델 데이터 개수 :  20

# %%
a = 0
for row in range(1, ws.max_row+1):
    #print(a)
    vegan = ws.cell(row,1).value
    print(vegan)
    a = a+1
    print("종료시점 a : " ,a)
    print("="*10)

# %%
with app.app_context():
    print(User.query.count())
    try:
        user = User(username='shin12352', password='shin_123452', email='shin52@naver.com')
        print(user)
        db.session.add(user)
        db.session.commit()
        print(User.query.count())
        print('사용자 정보를 생성 하였습니다.')
    except:
        db.session.rollback()
        #raise
        print('사용중인 사용자 정보가 있습니다.')
        pass
    finally:
        db.session.close()
    #db.create_all()
print('종료')
